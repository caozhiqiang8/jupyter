# %% [markdown]
# #  前置准备

# %%
# !pip install elasticsearch
# !pip install pyecharts 
# !pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-1.2.0-cp38-cp38-win_amd64.whl (9.3 MB)
# Requirement already satisfied: pytz>=2017.3 in c:\users\caozhiqiang\anaconda3\lib\site-packages (from pandas) (2020.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\caozhiqiang\anaconda3\lib\site-packages (from pandas) (2.8.1)
# Collecting numpy>=1.16.5
#   Downloading numpy-1.19.5-cp38-cp38-win_amd64.whl (13.3 MB)
# Requirement already satisfied: six>=1.5 in c:\users\caozhiqiang\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Installing collected packages: numpy, pandas
# Successfully installed numpy-1.19.5 pandas-1.2.0
# ^C

# %%
from pyecharts.globals import CurrentConfig, NotebookType
CurrentConfig.NOTEBOOK_TYPE = NotebookType.JUPYTER_LAB

# %%
import pandas as pd
import pymysql
import numpy as np
from sqlalchemy import create_engine
from elasticsearch import Elasticsearch
import datetime
import os
from functools import reduce
from matplotlib import pyplot as plt 


from pyecharts import options as opts
from pyecharts.charts import Line,Bar,Pie

# %% [markdown]
# ## 数据库连接

# %%
#连接es时host只写ip
es_hosts = str("52.82.47.234,52.83.95.66").split(",")
es = Elasticsearch(es_hosts)

#链接mysql
def mysqlDB(sql):
    engine = create_engine(
        'mysql+pymysql://schu:slavep@123.103.75.152:3306/school')
    result = pd.read_sql_query(sql = sql, con = engine)
    return result

#链接sqlite
def sqliteDB(sql):
    engine = create_engine('sqlite:///F:\\PythonObject\\SchoolObject\\db.sqlite3') 
    result = pd.read_sql(sql = sql, con = engine)
    return result

# %% [markdown]
# ## 初始化DataFram显示

# %%
# %%HTML
# <style type="text/css">
# table.dataframe td, table.dataframe th {
#     border: 1px  black solid !important;
#   color: black !important;
# }
# Out:
# <style type="text/css">
# table.dataframe td, table.dataframe th {
#     border: 1px  black solid !important;
#   color: black !important;
# }

# %%
# 显示所有行
pd.set_option("display.max_rows", None)
# 显示所有列
pd.set_option("display.max_columns", None)
# 保留小数点后几位
pd.set_option('precision', 0)
#取消科学计数法
pd.set_option("display.float_format", lambda x: "%.1f" % x)

now_time = datetime.datetime.strftime(datetime.datetime.today(),'%Y%m%d')

# %% [markdown]
# # 数据同步

# %%
import sqlite3

con = sqlite3.connect('F:\\PythonObject\\SchoolObject\\db.sqlite3')


def mysqlSqlite(sql, db_name):
    
    mysqlDB(sql = sql).to_sql(name=db_name, con=con,if_exists='replace', index=False)

    return '同步成功'

# %% [markdown]
# ## 教学数据同步

# %%
# school_course_task
school_course_task_sql = '''
         SELECT fr.school_id,fr.name,tc.course_id,tc.course_name ,g.grade_name,s.subject_name ,tt.task_id,tt.task_full_name,tt.c_user_id ,t.teacher_name ,tt.task_type ,tt.c_time,tt.correct_model
        FROM tp_task_info tt ,tp_course_info tc,franchised_school_info fr,teacher_info t,tp_j_course_class tjc,subject_info s,grade_info g 
        WHERE tc.DC_SCHOOL_ID = fr.school_id  and tc.course_id = tt.COURSE_ID  and fr.school_id >50000 and fr.enable = 0 and tt.c_time  >'2020-7-15 0:00:00'  and tc.LOCAL_STATUS = 1 
        and fr.school_type in (3,4) and tt.C_USER_ID = t.user_id and tjc.course_id = tc.course_id  and tjc.subject_id = s.subject_id and tjc.grade_id = g.grade_id 
        '''
mysqlSqlite(sql=school_course_task_sql, db_name='school_course_task')


# j_task_class
task_class_sql = '''
   SELECT task_id ,user_type_id as task_class_count FROM tp_task_allot_info where user_type = 0   and c_time  >'2020-7-15 0:00:00'

'''
mysqlSqlite(sql=task_class_sql, db_name='j_task_class')


# j_task_group
task_group_sql = '''
    SELECT tta.task_id ,tg.class_id   
    FROM tp_task_allot_info tta LEFT JOIN  tp_group_info tg on  tg.group_id = tta.user_type_id 
    where tta.user_type = 2  
    and tta.c_time  >'2020-7-15 0:00:00'

'''
mysqlSqlite(sql=task_group_sql, db_name='j_task_group')
# Out:
# '同步成功'

# %% [markdown]
# ## 资源数据同步

# %%
#课件
word_grade_subject_sql = ('''
        SELECT g.grade_name,s.subject_name,COUNT(DISTINCT r.res_id) "word_count"
        FROM 
        rs_resource_info r,tp_j_course_resource_info tr,
        tp_course_info tc,`tp_j_course_teaching_material` ttm
        ,`teaching_material_info` tm
        ,`teach_version_info` tv
        ,grade_info g
        ,subject_info s
        WHERE tr.`course_id` = ttm.`course_id`
        AND r.res_id  = tr.`res_id`
        AND tc.`COURSE_ID` > 0 
        AND tc.`COURSE_ID` = tr.`course_id`
        AND ttm.`teaching_material_id` = tm.`material_id` AND tm.`version_id` =  tv.`version_id`
        AND tm.`grade_id` = g.`GRADE_ID` AND tm.`subject_id` = s.`SUBJECT_ID`
        AND tc.`LOCAL_STATUS` = 1
        AND r.`diff_type` = 0
        AND r.res_id > 0 
        AND r.`RES_STATUS` = 1
        GROUP BY g.grade_id,s.subject_id
        ORDER BY g.grade_id,s.subject_id
             ''')
word_grade_subject_count = mysqlDB(word_grade_subject_sql)

#关联学案的微课
mp4_word_grade_subject_sql = ('''
        SELECT g.grade_name,s.subject_name,COUNT(DISTINCT r.res_id) as 'mp4_word_count'
        FROM 
        rs_resource_info r,tp_j_course_resource_info tr,
        tp_course_info tc,`tp_j_course_teaching_material` ttm
        ,`teaching_material_info` tm
        ,`teach_version_info` tv
        ,grade_info g
        ,subject_info s
        ,tp_study_j_module_resource aaa
        , j_mic_video_paper bbb
        WHERE tr.`course_id` = ttm.`course_id`
        AND r.res_id  = tr.`res_id`
        AND tc.`COURSE_ID` > 0 
        AND tc.`COURSE_ID` = tr.`course_id`
        AND ttm.`teaching_material_id` = tm.`material_id` AND tm.`version_id` =  tv.`version_id`
        AND tm.`grade_id` = g.`GRADE_ID` AND tm.`subject_id` = s.`SUBJECT_ID`
        AND tc.`LOCAL_STATUS` = 1
        AND aaa.resource_id = r.res_id
        AND aaa.resource_type = 32
        AND r.`diff_type` = 1
        AND r.res_id > 0 
        AND r.`RES_STATUS` = 1
        AND bbb.`mic_video_id` = r.res_id
        AND EXISTS(
          SELECT 1 FROM tp_study_j_module_resource ppp
           WHERE aaa.module_id=ppp.module_id
        AND  ppp.resource_type=33
        )
        GROUP BY g.grade_id,s.subject_id
        ORDER BY g.grade_id,s.subject_id
             ''')
mp4_word_grade_subject_count = mysqlDB(mp4_word_grade_subject_sql)

#微课关联的学案
word_mp4_grade_subject_sql = ('''
        SELECT g.grade_name,s.subject_name, COUNT(DISTINCT r.res_id) as 'word_mp4_count'
        FROM 
        rs_resource_info r,tp_j_course_resource_info tr,
        tp_course_info tc,`tp_j_course_teaching_material` ttm
        ,`teaching_material_info` tm
        ,`teach_version_info` tv
        ,grade_info g
        ,subject_info s
        ,tp_study_j_module_resource aaa
        WHERE tr.`course_id` = ttm.`course_id`
        AND r.res_id  = tr.`res_id`
        AND tc.`COURSE_ID` > 0 
        AND tc.`COURSE_ID` = tr.`course_id`
        AND ttm.`teaching_material_id` = tm.`material_id` AND tm.`version_id` =  tv.`version_id`
        AND tm.`grade_id` = g.`GRADE_ID` AND tm.`subject_id` = s.`SUBJECT_ID`
        AND tc.`LOCAL_STATUS` = 1
        AND aaa.resource_id = r.res_id
        AND aaa.resource_type = 33
        AND r.`diff_type` = 0
        AND r.res_id > 0 
        AND r.`RES_STATUS` = 1
        AND EXISTS(
          SELECT 1 FROM tp_study_j_module_resource ppp
           WHERE aaa.module_id=ppp.module_id
        AND  ppp.resource_type=32
        )
        GROUP BY g.grade_id,s.subject_id
        ORDER BY g.grade_id,s.subject_id
                     ''')
word_mp4_grade_subject_count = mysqlDB(word_mp4_grade_subject_sql)

#微课
mp4_grade_subject_sql = ('''
        SELECT g.grade_name,s.subject_name,COUNT(DISTINCT r.res_id) "mp4_count"
        FROM 
        rs_resource_info r,tp_j_course_resource_info tr,
        tp_course_info tc,`tp_j_course_teaching_material` ttm
        ,`teaching_material_info` tm
        ,`teach_version_info` tv
        ,grade_info g
        ,subject_info s
        WHERE tr.`course_id` = ttm.`course_id`
        AND r.res_id  = tr.`res_id`
        AND tc.`COURSE_ID` > 0 
        AND tc.`COURSE_ID` = tr.`course_id`
        AND ttm.`teaching_material_id` = tm.`material_id` AND tm.`version_id` =  tv.`version_id`
        AND tm.`grade_id` = g.`GRADE_ID` AND tm.`subject_id` = s.`SUBJECT_ID`
        AND tc.`LOCAL_STATUS` = 1
        AND r.`diff_type` = 1
        AND r.res_id > 0 
        AND r.`RES_STATUS` = 1
        GROUP BY g.grade_id,s.subject_id
        ORDER BY g.grade_id,s.subject_id
             ''')
mp4_grade_subject_count = mysqlDB(mp4_grade_subject_sql)

#成卷
cpaper_grade_subject_sql = ('''
        SELECT g.grade_name,s.subject_name,COUNT(DISTINCT p.paper_id) "cpaper_count" FROM `online_test_paper_info` p,subject_info s,grade_info g 
        WHERE paper_id > 0
        AND g.grade_id = p.grade_id
        AND s.subject_id= p.subject_id
        AND paper_status = 1
        GROUP BY g.grade_id,s.subject_id
        ORDER BY g.grade_id,s.subject_id
             ''')
cpaper_grade_subject_count = mysqlDB(cpaper_grade_subject_sql)
    
#AB卷
paper_grade_subject_sql = ('''
        SELECT g.grade_name,s.subject_name,COUNT(DISTINCT p.paper_id) "paper_count"
        FROM paper_info p
        ,tp_j_course_paper tr
        ,tp_course_info tc
        ,tp_j_course_teaching_material ttm
        ,teach_version_info tv
        ,teaching_material_info tm
        ,grade_info g
        ,subject_info s
        WHERE tr.`course_id` = ttm.`course_id`
        AND p.paper_id = tr.`paper_id`
        AND tc.`COURSE_ID` > 0
        AND tc.`COURSE_ID` = tr.`course_id`
        AND ttm.`teaching_material_id` = tm.`material_id`
        AND tm.`version_id` = tv.`version_id`
        AND tm.`grade_id` = g.`GRADE_ID`
        AND tm.`subject_id` = s.`SUBJECT_ID`
        AND tc.`LOCAL_STATUS` = 1
        AND p.paper_id > 0 
        AND p.`paper_type` IN (1,2)
        GROUP BY g.grade_id,s.subject_id
        ORDER BY g.grade_id,s.subject_id
             ''')
paper_grade_subject_count = mysqlDB(paper_grade_subject_sql)

#试题
ques_grade_subject_sql = ('''
        SELECT g.grade_name,s.subject_name,COUNT(DISTINCT q.question_id) "question_count"
        FROM question_info q
        ,tp_j_course_question_info tr
        ,tp_course_info tc
        ,tp_j_course_teaching_material ttm
        ,teach_version_info tv
        ,teaching_material_info tm
        ,grade_info g
        ,subject_info s
        WHERE tr.`course_id` = ttm.`course_id`
        AND q.question_id = tr.`question_id`
        AND tc.`COURSE_ID` > 0
        AND tc.`COURSE_ID` = tr.`course_id`
        AND ttm.`teaching_material_id` = tm.`material_id`
        AND tm.`version_id` = tv.`version_id`
        AND tm.`grade_id` = g.`GRADE_ID`
        AND tm.`subject_id` = s.`SUBJECT_ID`
        AND tc.`LOCAL_STATUS` = 1
        AND q.`question_id` > 0 
        GROUP BY g.grade_id,s.subject_id
        ORDER BY g.grade_id,s.subject_id
             ''')
ques_grade_subject_count = mysqlDB(ques_grade_subject_sql)


#合并表格
#word_grade_subject_count - 课件
#word_mp4_grade_subject_count - 微课关联的学案
#mp4_grade_subject_count - 微课
#mp4_word_grade_subject_count - 关联学案的微课
#cpaper_grade_subject_count - 成卷
#paper_grade_subject_count - AB卷
#ques_grade_subject_count - 试题

res_dfs = [word_grade_subject_count,
           word_mp4_grade_subject_count,
           mp4_grade_subject_count,
           mp4_word_grade_subject_count,
           cpaper_grade_subject_count,
           paper_grade_subject_count,
           ques_grade_subject_count]
df_merge= reduce(lambda left,right: pd.merge(left,right,on=['grade_name','subject_name'],how = 'left'), res_dfs)


# 填充空缺数据为0
res_count = df_merge.fillna(0)


# resource_info
res_count.to_sql(name='resource_info', con=con,if_exists='replace', index=False)
print('同步成功')
# Out:
# 同步成功

# %% [markdown]
# # 基础数据

# %% [markdown]
# ## 学校数据

# %%
school_sql = '''
        
SELECT fr.school_id ,fr.name ,s.province,s.city,fr.c_time,fr.validity_time
        from franchised_school_info fr,school_info s where fr.school_type in (3,4) 
        and fr.school_id  >50000 and fr.enable = 0  and s.school_id = fr.school_id 
        '''
school = mysqlDB(school_sql)

# %%
school.head()
# Out:
#    school_id       name province city              c_time validity_time
# 0      50028  北京市第三十九中学       北京   北京 2014-07-08 12:07:45    2020-06-01
# 1      50034    成都市大弯中学       四川   成都 2014-08-19 15:07:43    2021-11-17
# 2      50039  成都市人民北路中学       四川   成都 2014-09-09 17:17:28    2020-11-07
# 3      50043    大连分校910       广东   东莞 2014-09-11 17:49:59    2025-08-05
# 4      50054  安康市高新国际中学       陕西   安康 2014-09-17 18:18:06    2020-06-01

# %%
school.sort_values(by = 'c_time', ascending = False).reset_index( drop = True).head()
# Out:
#    school_id          name province city              c_time validity_time
# 0  100002281       广元市第二中学       四川   广元 2021-01-11 13:26:15    2022-01-11
# 1  100002280  贵阳市白云区第六初级中学       贵州   贵阳 2021-01-08 09:52:42    2022-01-08
# 2  100002278        长春未来学校       吉林   长春 2021-01-05 10:07:27    2022-01-05
# 3  100002277    山西晋中分校演示学校       山西   晋中 2021-01-04 14:32:42    2022-01-04
# 4  100002275       兴义市阳光书院       贵州   兴义 2020-12-30 15:11:20    2021-12-30

# %%
school['c_dttime'] = school['c_time'].dt.strftime('%Y-%m')
# school['c_dttime'] = pd.to_datetime(school['c_time'], format='%Y-%m').dt.date

school.append(school['c_dttime'])
school_data = school['c_dttime'].groupby(school['c_dttime']).agg('count')
school_data['2017-09'] = 43

# %%
# school_data.sort_values(asending = False)
# school_data = school_data[-24:-1]

# %%
x_data = school_data.index.tolist()
y_data =  school_data.values.tolist()
x_data
# Out:
# ['2014-07',
#  '2014-08',
#  '2014-09',
#  '2014-10',
#  '2014-11',
#  '2014-12',
#  '2015-01',
#  '2015-02',
#  '2015-03',
#  '2015-04',
#  '2015-05',
#  '2015-06',
#  '2015-07',
#  '2015-08',
#  '2015-09',
#  '2015-10',
#  '2015-11',
#  '2015-12',
#  '2016-01',
#  '2016-02',
#  '2016-03',
#  '2016-04',
#  '2016-05',
#  '2016-06',
#  '2016-07',
#  '2016-08',
#  '2016-09',
#  '2016-10',
#  '2016-11',
#  '2016-12',
#  '2017-01',
#  '2017-02',
#  '2017-03',
#  '2017-04',
#  '2017-05',
#  '2017-06',
#  '2017-07',
#  '2017-08',
#  '2017-09',
#  '2017-10',
#  '2017-11',
#  '2017-12',
#  '2018-01',
#  '2018-03',
#  '2018-04',
#  '2018-05',
#  '2018-06',
#  '2018-07',
#  '2018-08',
#  '2018-09',
#  '2018-10',
#  '2018-11',
#  '2018-12',
#  '2019-01',
#  '2019-02',
#  '2019-03',
#  '2019-04',
#  '2019-05',
#  '2019-06',
#  '2019-07',
#  '2019-08',
#  '2019-09',
#  '2019-10',
#  '2019-11',
#  '2019-12',
#  '2020-01',
#  '2020-02',
#  '2020-03',
#  '2020-04',
#  '2020-05',
#  '2020-06',
#  '2020-07',
#  '2020-08',
#  '2020-09',
#  '2020-10',
#  '2020-11',
#  '2020-12',
#  '2021-01']

# %%
y_data
# Out:
# [1,
#  1,
#  3,
#  8,
#  3,
#  77,
#  52,
#  12,
#  21,
#  36,
#  17,
#  22,
#  20,
#  13,
#  51,
#  49,
#  36,
#  43,
#  33,
#  4,
#  54,
#  37,
#  38,
#  26,
#  25,
#  41,
#  80,
#  20,
#  53,
#  46,
#  50,
#  14,
#  30,
#  41,
#  36,
#  17,
#  9,
#  123,
#  43,
#  36,
#  57,
#  15,
#  10,
#  30,
#  20,
#  15,
#  57,
#  41,
#  33,
#  48,
#  25,
#  23,
#  17,
#  13,
#  5,
#  3,
#  112,
#  8,
#  16,
#  3,
#  25,
#  25,
#  13,
#  13,
#  110,
#  179,
#  276,
#  15,
#  13,
#  7,
#  5,
#  6,
#  28,
#  19,
#  40,
#  43,
#  37,
#  4]

# %%
bar = Bar(init_opts = opts.InitOpts(width = '1200px'))
bar.add_xaxis(x_data)
bar.add_yaxis("开通学校数量", y_data)
bar.set_global_opts(
    title_opts=opts.TitleOpts(title="开通学校图"),
    datazoom_opts = opts.DataZoomOpts( is_show = True , type_ ='slider',range_start = 70,range_end = 100),

)

bar.set_series_opts(
    label_opts = opts.LabelOpts(is_show=True),
    markline_opts=opts.MarkLineOpts(
            data=[

                opts.MarkLineItem(type_="average", name="平均值"),
            ]
        ),
    markpoint_opts=opts.MarkPointOpts(
            data=[
                opts.MarkPointItem(type_="min", name="最小值"),
                opts.MarkPointItem(type_="max", name="最大值"),
            ]
        ),

    )

# %%
bar.load_javascript()

# %%
bar.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="9b3455560caf4e3993b1bd33c887fe05" class="chart-container" style="width:1200px; height:500px;"></div>
#     <script>
#         var chart_9b3455560caf4e3993b1bd33c887fe05 = echarts.init(
#             document.getElementById('9b3455560caf4e3993b1bd33c887fe05'), 'white', {renderer: 'canvas'});
#         var option_9b3455560caf4e3993b1bd33c887fe05 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5f00\u901a\u5b66\u6821\u6570\u91cf",
#             "legendHoverLink": true,
#             "data": [
#                 1,
#                 1,
#                 3,
#                 8,
#                 3,
#                 77,
#                 52,
#                 12,
#                 21,
#                 36,
#                 17,
#                 22,
#                 20,
#                 13,
#                 51,
#                 49,
#                 36,
#                 43,
#                 33,
#                 4,
#                 54,
#                 37,
#                 38,
#                 26,
#                 25,
#                 41,
#                 80,
#                 20,
#                 53,
#                 46,
#                 50,
#                 14,
#                 30,
#                 41,
#                 36,
#                 17,
#                 9,
#                 123,
#                 43,
#                 36,
#                 57,
#                 15,
#                 10,
#                 30,
#                 20,
#                 15,
#                 57,
#                 41,
#                 33,
#                 48,
#                 25,
#                 23,
#                 17,
#                 13,
#                 5,
#                 3,
#                 112,
#                 8,
#                 16,
#                 3,
#                 25,
#                 25,
#                 13,
#                 13,
#                 110,
#                 179,
#                 276,
#                 15,
#                 13,
#                 7,
#                 5,
#                 6,
#                 28,
#                 19,
#                 40,
#                 43,
#                 37,
#                 4
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "name": "\u6700\u5c0f\u503c",
#                         "type": "min"
#                     },
#                     {
#                         "name": "\u6700\u5927\u503c",
#                         "type": "max"
#                     }
#                 ]
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "name": "\u5e73\u5747\u503c",
#                         "type": "average"
#                     }
#                 ]
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5f00\u901a\u5b66\u6821\u6570\u91cf"
#             ],
#             "selected": {
#                 "\u5f00\u901a\u5b66\u6821\u6570\u91cf": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "2014-07",
#                 "2014-08",
#                 "2014-09",
#                 "2014-10",
#                 "2014-11",
#                 "2014-12",
#                 "2015-01",
#                 "2015-02",
#                 "2015-03",
#                 "2015-04",
#                 "2015-05",
#                 "2015-06",
#                 "2015-07",
#                 "2015-08",
#                 "2015-09",
#                 "2015-10",
#                 "2015-11",
#                 "2015-12",
#                 "2016-01",
#                 "2016-02",
#                 "2016-03",
#                 "2016-04",
#                 "2016-05",
#                 "2016-06",
#                 "2016-07",
#                 "2016-08",
#                 "2016-09",
#                 "2016-10",
#                 "2016-11",
#                 "2016-12",
#                 "2017-01",
#                 "2017-02",
#                 "2017-03",
#                 "2017-04",
#                 "2017-05",
#                 "2017-06",
#                 "2017-07",
#                 "2017-08",
#                 "2017-09",
#                 "2017-10",
#                 "2017-11",
#                 "2017-12",
#                 "2018-01",
#                 "2018-03",
#                 "2018-04",
#                 "2018-05",
#                 "2018-06",
#                 "2018-07",
#                 "2018-08",
#                 "2018-09",
#                 "2018-10",
#                 "2018-11",
#                 "2018-12",
#                 "2019-01",
#                 "2019-02",
#                 "2019-03",
#                 "2019-04",
#                 "2019-05",
#                 "2019-06",
#                 "2019-07",
#                 "2019-08",
#                 "2019-09",
#                 "2019-10",
#                 "2019-11",
#                 "2019-12",
#                 "2020-01",
#                 "2020-02",
#                 "2020-03",
#                 "2020-04",
#                 "2020-05",
#                 "2020-06",
#                 "2020-07",
#                 "2020-08",
#                 "2020-09",
#                 "2020-10",
#                 "2020-11",
#                 "2020-12",

# %% [markdown]
# ## 学校、班级、教师、学生 数据

# %%
school_class_sql = '''
         SELECT fr.school_id,fr.name,count(distinct c.class_id) as '班级数', count(distinct axp.class_id) as '爱学派班级数', tea.tea_count as '教师人数',stu.stu_count as '学生人数'
        from  franchised_school_info fr LEFT JOIN class_info c on fr.school_id = c.dc_school_id
        LEFT JOIN ( SELECT c.DC_SCHOOL_ID , count(DISTINCT jc.user_id ) as 'tea_count' from j_class_user jc ,class_info c  where c.year = '2020~2021' and c.class_id = jc.class_id and jc.RELATION_TYPE = '任课老师' GROUP BY c.DC_SCHOOL_ID  ) tea  on tea.DC_SCHOOL_ID = fr.school_id
        LEFT JOIN ( SELECT c.DC_SCHOOL_ID , count(DISTINCT jc.user_id ) as 'stu_count' from j_class_user jc ,class_info c  where c.year = '2020~2021' and c.class_id = jc.class_id and jc.RELATION_TYPE = '学生' GROUP BY c.DC_SCHOOL_ID  ) stu on stu.DC_SCHOOL_ID = fr.school_id
        LEFT JOIN (SELECT class_id,DC_SCHOOL_ID from class_info where year = '2020~2021'  and axp_end_time >NOW() ) axp on axp.DC_SCHOOL_ID = fr.school_id
        where fr.school_type in (3,4) and fr.school_id  >50000 and fr.enable = 0 and c.year = '2020~2021' 
        group by fr.school_id
        '''
school_class = mysqlDB(school_class_sql)

# %%
school_class = school_class.fillna(0)
# 指定字段 数据类型。
# school[['school_id','tea_count','stu_count']] = school[['school_id','tea_count','stu_count']].astype({'school_id':str,'tea_count':'int64','stu_count':'int64'})
school_class.head()
# Out:
#    school_id         name  班级数  爱学派班级数   教师人数   学生人数
# 0      50034      成都市大弯中学    3       0   23.0  133.0
# 1      50039    成都市人民北路中学    6       0   18.0  260.0
# 2      50043      大连分校910  265      40 1377.0  931.0
# 3      50083  成都市龙泉驿区第一中学   54      42  229.0 2100.0
# 4      50092     成都铁中线上学校   48       0  191.0 2302.0

# %% [markdown]
# # 任务数据

# %% [markdown]
# ## 平台任务分布

# %%
school_course_task_sql = 'SELECT * FROM school_course_task  '
school_course_task = sqliteDB(school_course_task_sql)

# %%
# c_time转 datatime 格式
school_course_task['c_time'] = pd.to_datetime(school_course_task['c_time'] )

# %%
task1_count = (school_course_task.loc[(school_course_task['task_type']== 1)].drop_duplicates(['task_id'])).agg('count')['task_id']

# %% [markdown]
# ###  任务类型占比

# %%
task1_count = (school_course_task.loc[(school_course_task['task_type']== 1)].drop_duplicates(['task_id'])).agg('count')['task_id']

task2_count = (school_course_task.loc[(school_course_task['task_type']== 2)].drop_duplicates(['task_id'])).agg('count')['task_id']

task3_count = (school_course_task.loc[(school_course_task['task_type']== 3)].drop_duplicates(['task_id'])).agg('count')['task_id']
task4_count = (school_course_task.loc[(school_course_task['task_type']== 4)].drop_duplicates(['task_id'])).agg('count')['task_id']
task6_count = (school_course_task.loc[(school_course_task['task_type']== 6)].drop_duplicates(['task_id'])).agg('count')['task_id']
task7_count = (school_course_task.loc[((school_course_task['task_type']== 7))|(school_course_task['task_type']== 8)|(school_course_task['task_type']== 9)].drop_duplicates(['task_id'])).agg('count')['task_id']
task10_count = (school_course_task.loc[(school_course_task['task_type']== 10)].drop_duplicates(['task_id'])).agg('count')['task_id']
task13_count = (school_course_task.loc[(school_course_task['task_type']== 13)].drop_duplicates(['task_id'])).agg('count')['task_id']
task14_count = (school_course_task.loc[(school_course_task['task_type']== 14)].drop_duplicates(['task_id'])).agg('count')['task_id']
task15_count = (school_course_task.loc[(school_course_task['task_type']== 15)].drop_duplicates(['task_id'])).agg('count')['task_id']

task_data_list = [
    ['学资源',int(task1_count)],
    ['讨论',int(task2_count)],
    ['单题',int(task3_count)],
    ['测验',int(task4_count)],
    ['微课程',int(task6_count)],
    ['一般任务',int(task7_count)],
    ['直播课',int(task10_count)],
    ['答题卡',int(task13_count)],
    ['个性化',int(task14_count)],
    ['先声',int(task15_count)],
]

# %%
from pyecharts import options as opts
from pyecharts.charts import Pie


pie = Pie()
pie.add(
        "",
        task_data_list,
        radius=["40%", "75%"],
    )
pie.set_global_opts(
        title_opts=opts.TitleOpts(title="任务分布比例"),
        legend_opts=opts.LegendOpts(orient="vertical", pos_top="15%", pos_left="2%"),
    )
pie.set_series_opts(label_opts=opts.LabelOpts(formatter="{b}：{c} ({d}%)"))
    
pie.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="438328caff5c4a7f9a197d577bc410e3" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_438328caff5c4a7f9a197d577bc410e3 = echarts.init(
#             document.getElementById('438328caff5c4a7f9a197d577bc410e3'), 'white', {renderer: 'canvas'});
#         var option_438328caff5c4a7f9a197d577bc410e3 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u5b66\u8d44\u6e90",
#                     "value": 186136
#                 },
#                 {
#                     "name": "\u8ba8\u8bba",
#                     "value": 10122
#                 },
#                 {
#                     "name": "\u5355\u9898",
#                     "value": 57833
#                 },
#                 {
#                     "name": "\u6d4b\u9a8c",
#                     "value": 75501
#                 },
#                 {
#                     "name": "\u5fae\u8bfe\u7a0b",
#                     "value": 76267
#                 },
#                 {
#                     "name": "\u4e00\u822c\u4efb\u52a1",
#                     "value": 12436
#                 },
#                 {
#                     "name": "\u76f4\u64ad\u8bfe",
#                     "value": 4006
#                 },
#                 {
#                     "name": "\u7b54\u9898\u5361",
#                     "value": 41001
#                 },
#                 {
#                     "name": "\u4e2a\u6027\u5316",
#                     "value": 1380
#                 },
#                 {
#                     "name": "\u5148\u58f0",
#                     "value": 5025
#                 }
#             ],
#             "radius": [
#                 "40%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}\uff1a{c} ({d}%)"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5b66\u8d44\u6e90",
#                 "\u8ba8\u8bba",
#                 "\u5355\u9898",
#                 "\u6d4b\u9a8c",
#                 "\u5fae\u8bfe\u7a0b",
#                 "\u4e00\u822c\u4efb\u52a1",
#                 "\u76f4\u64ad\u8bfe",
#                 "\u7b54\u9898\u5361",
#                 "\u4e2a\u6027\u5316",
#                 "\u5148\u58f0"
#             ],
#             "selected": {},
#             "show": true,
#             "left": "2%",
#             "top": "15%",
#             "orient": "vertical",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "\u4efb\u52a1\u5206\u5e03\u6bd4\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#         chart_438328caff5c4a7f9a197d577bc410e3.setOption(option_438328caff5c4a7f9a197d577bc410e3);
#     </script>
# </body>
# </html>

# %% [markdown]
# ### 平台任务趋势

# %%
# school_course_task_data = (school_course_task['c_time'].groupby(school_course_task['c_time'].dt.date)).agg('count')
school_course_task_data = (school_course_task.drop_duplicates(['task_id'])['c_time'].groupby(school_course_task['c_time'].dt.date)).agg('count')

school_course_task_x = school_course_task_data.index.tolist()
school_course_task_y = school_course_task_data.values.tolist()

# %%
#渲染图大小
line = Line(init_opts = opts.InitOpts(width = '1200px'))

#X轴数据
line.add_xaxis(school_course_task_x)
#Y轴名称和
line.add_yaxis("任务数量", school_course_task_y)

# 全局配置
line.set_global_opts(
    #主标题
    title_opts=opts.TitleOpts(title="每天任务趋势图"),
    # 缩放功能
    datazoom_opts = opts.DataZoomOpts( is_show = True , type_ ='slider',range_start = 70,range_end = 100),
    # x轴文字距离，旋转角度
#     xaxis_opts=opts.AxisOpts(
#             axislabel_opts={"interval":"0","rotate":45},
#         ),
     tooltip_opts=opts.TooltipOpts(trigger="axis"),
        yaxis_opts=opts.AxisOpts(
            type_="value",
            axistick_opts=opts.AxisTickOpts(is_show=True),
            xaxis_opts=opts.AxisOpts(
            axislabel_opts={"interval":"0","rotate":45},
        ),
            splitline_opts=opts.SplitLineOpts(is_show=True),
        ),
        xaxis_opts=opts.AxisOpts(type_="category", boundary_gap=False),
    
)

# 系统配置
line.set_series_opts(
    # 图中显示数值
    label_opts = opts.LabelOpts(is_show=True),

    # 线装图，平均线
    markline_opts=opts.MarkLineOpts(
        data=[opts.MarkLineItem(type_="average", name="平均值"),]
                                    ),
    # 点装图，最大值最小值
    markpoint_opts=opts.MarkPointOpts(
            data=[
                opts.MarkPointItem(type_="min", name="最小值"),
                opts.MarkPointItem(type_="max", name="最大值"),
            ]
        ),
)

# %%
line.load_javascript()

# %%
line.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="2d9f58eda7a64dd2846478d55ec5b990" class="chart-container" style="width:1200px; height:500px;"></div>
#     <script>
#         var chart_2d9f58eda7a64dd2846478d55ec5b990 = echarts.init(
#             document.getElementById('2d9f58eda7a64dd2846478d55ec5b990'), 'white', {renderer: 'canvas'});
#         var option_2d9f58eda7a64dd2846478d55ec5b990 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u4efb\u52a1\u6570\u91cf",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "2020-07-15",
#                     3449
#                 ],
#                 [
#                     "2020-07-16",
#                     2626
#                 ],
#                 [
#                     "2020-07-17",
#                     2826
#                 ],
#                 [
#                     "2020-07-18",
#                     1089
#                 ],
#                 [
#                     "2020-07-19",
#                     1990
#                 ],
#                 [
#                     "2020-07-20",
#                     3042
#                 ],
#                 [
#                     "2020-07-21",
#                     2256
#                 ],
#                 [
#                     "2020-07-22",
#                     1637
#                 ],
#                 [
#                     "2020-07-23",
#                     1677
#                 ],
#                 [
#                     "2020-07-24",
#                     1765
#                 ],
#                 [
#                     "2020-07-25",
#                     1519
#                 ],
#                 [
#                     "2020-07-26",
#                     1401
#                 ],
#                 [
#                     "2020-07-27",
#                     1773
#                 ],
#                 [
#                     "2020-07-28",
#                     1252
#                 ],
#                 [
#                     "2020-07-29",
#                     1282
#                 ],
#                 [
#                     "2020-07-30",
#                     1432
#                 ],
#                 [
#                     "2020-07-31",
#                     1166
#                 ],
#                 [
#                     "2020-08-01",
#                     1148
#                 ],
#                 [
#                     "2020-08-02",
#                     1240
#                 ],
#                 [
#                     "2020-08-03",
#                     1648
#                 ],
#                 [
#                     "2020-08-04",
#                     1355
#                 ],
#                 [
#                     "2020-08-05",
#                     1137
#                 ],
#                 [
#                     "2020-08-06",
#                     1239
#                 ],
#                 [
#                     "2020-08-07",
#                     1590
#                 ],
#                 [
#                     "2020-08-08",
#                     2111
#                 ],
#                 [
#                     "2020-08-09",
#                     2719
#                 ],
#                 [
#                     "2020-08-10",
#                     1368
#                 ],
#                 [
#                     "2020-08-11",
#                     1954
#                 ],
#                 [
#                     "2020-08-12",
#                     1289
#                 ],
#                 [
#                     "2020-08-13",
#                     1330
#                 ],
#                 [
#                     "2020-08-14",
#                     1180
#                 ],
#                 [
#                     "2020-08-15",
#                     985
#                 ],
#                 [
#                     "2020-08-16",
#                     1218
#                 ],
#                 [
#                     "2020-08-17",
#                     1477
#                 ],
#                 [
#                     "2020-08-18",
#                     1670
#                 ],
#                 [
#                     "2020-08-19",
#                     1221
#                 ],
#                 [
#                     "2020-08-20",
#                     1292
#                 ],
#                 [
#                     "2020-08-21",
#                     989
#                 ],
#                 [
#                     "2020-08-22",
#                     873
#                 ],
#                 [
#                     "2020-08-23",
#                     811
#                 ],
#                 [
#                     "2020-08-24",
#                     783
#                 ],
#                 [
#                     "2020-08-25",
#                     836
#                 ],
#                 [
#                     "2020-08-26",
#                     948
#                 ],
#                 [
#                     "2020-08-27",
#                     1170
#                 ],
#                 [
#                     "2020-08-28",
#                     602
#                 ],
#                 [
#                     "2020-08-29",
#                     563
#                 ],
#                 [
#                     "2020-08-30",
#                     675
#                 ],
#                 [
#                     "2020-08-31",
#                     1454
#                 ],
#                 [
#                     "2020-09-01",
#                     1414
#                 ],
#                 [
#                     "2020-09-02",
#                     1676
#                 ],
#                 [
#                     "2020-09-03",
#                     2079
#                 ],
#                 [
#                     "2020-09-04",
#                     2275
#                 ],
#                 [
#                     "2020-09-05",
#                     2869
#                 ],
#                 [
#                     "2020-09-06",
#                     769
#                 ],
#                 [
#                     "2020-09-07",
#                     2565
#                 ],
#                 [
#                     "2020-09-08",
#                     3032
#                 ],
#                 [
#                     "2020-09-09",
#                     2805
#                 ],
#                 [
#                     "2020-09-10",
#                     2310
#                 ],
#                 [
#                     "2020-09-11",
#                     2716
#                 ],
#                 [
#                     "2020-09-12",
#                     1213
#                 ],
#                 [
#                     "2020-09-13",
#                     898
#                 ],
#                 [
#                     "2020-09-14",
#                     2837
#                 ],
#                 [
#                     "2020-09-15",
#                     3489
#                 ],
#                 [
#                     "2020-09-16",
#                     3386
#                 ],
#                 [
#                     "2020-09-17",
#                     3311
#                 ],
#                 [
#                     "2020-09-18",
#                     3380
#                 ],
#                 [
#                     "2020-09-19",
#                     1088
#                 ],
#                 [
#                     "2020-09-20",
#                     1004
#                 ],
#                 [

# %% [markdown]
# ### 各类型趋势图

# %%
school_course_task1 = school_course_task.drop_duplicates(['task_id']).loc[(school_course_task['task_type']== 1)]
school_course_task2 = school_course_task.drop_duplicates(['task_id']).loc[(school_course_task['task_type']== 2)]
school_course_task3 = school_course_task.drop_duplicates(['task_id']).loc[(school_course_task['task_type']== 3)]
school_course_task4 = school_course_task.drop_duplicates(['task_id']).loc[(school_course_task['task_type']== 4)]
school_course_task6 = school_course_task.drop_duplicates(['task_id']).loc[(school_course_task['task_type']== 6)]
school_course_task7 = school_course_task.drop_duplicates(['task_id']).loc[((school_course_task['task_type']== 7))|(school_course_task['task_type']== 8)|(school_course_task['task_type']== 9)]
school_course_task10 = school_course_task.drop_duplicates(['task_id']).loc[(school_course_task['task_type']== 10)]
school_course_task13 = school_course_task.drop_duplicates(['task_id']).loc[(school_course_task['task_type']== 13)]
school_course_task14 = school_course_task.drop_duplicates(['task_id']).loc[(school_course_task['task_type']== 14)]
school_course_task15 = school_course_task.drop_duplicates(['task_id']).loc[(school_course_task['task_type']== 15)]

# %%
school_course_task1_data = (school_course_task1)['c_time'].groupby(school_course_task1['c_time'].dt.date).agg('count')
school_course_task2_data = school_course_task2['c_time'].groupby(school_course_task2['c_time'].dt.date).agg('count')
school_course_task3_data = school_course_task3['c_time'].groupby(school_course_task3['c_time'].dt.date).agg('count')
school_course_task4_data = school_course_task4['c_time'].groupby(school_course_task4['c_time'].dt.date).agg('count')
school_course_task6_data = school_course_task6['c_time'].groupby(school_course_task6['c_time'].dt.date).agg('count')
school_course_task7_data = school_course_task7['c_time'].groupby(school_course_task7['c_time'].dt.date).agg('count')
school_course_task10_data = school_course_task10['c_time'].groupby(school_course_task10['c_time'].dt.date).agg('count')
school_course_task13_data = school_course_task13['c_time'].groupby(school_course_task13['c_time'].dt.date).agg('count')
school_course_task14_data = school_course_task14['c_time'].groupby(school_course_task14['c_time'].dt.date).agg('count')
school_course_task15_data = school_course_task15['c_time'].groupby(school_course_task15['c_time'].dt.date).agg('count')


school_course_task1_x = school_course_task1_data.index.tolist()

school_course_task1_y = school_course_task1_data.values.tolist()
school_course_task2_y = school_course_task2_data.values.tolist()
school_course_task3_y = school_course_task3_data.values.tolist()
school_course_task4_y = school_course_task4_data.values.tolist()
school_course_task6_y = school_course_task6_data.values.tolist()
school_course_task7_y = school_course_task7_data.values.tolist()
school_course_task10_y = school_course_task10_data.values.tolist()
school_course_task13_y = school_course_task13_data.values.tolist()
school_course_task14_y = school_course_task14_data.values.tolist()
school_course_task15_y = school_course_task15_data.values.tolist()

# %%
#渲染图大小
line = Line(init_opts = opts.InitOpts(width = '1000px'))

#X轴数据
line.add_xaxis(school_course_task1_x)

#Y轴名称和
# line.add_yaxis("学资源", school_course_task1_y)
# line.add_yaxis("讨论", school_course_task2_y)
# line.add_yaxis("单个试题", school_course_task3_y)
# line.add_yaxis("微课", school_course_task6_y)
# line.add_yaxis("一般任务", school_course_task7_y)
# line.add_yaxis("直播课", school_course_task10_y)
# line.add_yaxis("个性化", school_course_task14_y)
# line.add_yaxis("先声", school_course_task15_y)

line.add_yaxis("答题卡", school_course_task13_y)
line.add_yaxis("测验", school_course_task4_y)


# 全局配置
line.set_global_opts(
    #主标题
    title_opts=opts.TitleOpts(title="任务趋势图"),
    # 缩放功能
    datazoom_opts = opts.DataZoomOpts( is_show = True , type_ ='slider',range_start = 70,range_end = 100),
    # x轴文字距离，旋转角度
    xaxis_opts=opts.AxisOpts(
            axislabel_opts={"interval":"0","rotate":45},
        ),
)

# 系统配置
line.set_series_opts(
    # 图中显示数值
    label_opts = opts.LabelOpts(is_show=True),


    # 线装图，平均线
    markline_opts=opts.MarkLineOpts(
        data=[opts.MarkLineItem(type_="average", name="平均值"),]
                                    ),
    # 点装图，最大值最小值
    markpoint_opts=opts.MarkPointOpts(
            data=[
                opts.MarkPointItem(type_="min", name="最小值"),
                opts.MarkPointItem(type_="max", name="最大值"),
            ]
        ),
)
line.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="9c6008e8ea534fc4a0ffae75aa9b12c9" class="chart-container" style="width:1000px; height:500px;"></div>
#     <script>
#         var chart_9c6008e8ea534fc4a0ffae75aa9b12c9 = echarts.init(
#             document.getElementById('9c6008e8ea534fc4a0ffae75aa9b12c9'), 'white', {renderer: 'canvas'});
#         var option_9c6008e8ea534fc4a0ffae75aa9b12c9 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u7b54\u9898\u5361",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "2020-07-15",
#                     219
#                 ],
#                 [
#                     "2020-07-16",
#                     169
#                 ],
#                 [
#                     "2020-07-17",
#                     133
#                 ],
#                 [
#                     "2020-07-18",
#                     55
#                 ],
#                 [
#                     "2020-07-19",
#                     67
#                 ],
#                 [
#                     "2020-07-20",
#                     72
#                 ],
#                 [
#                     "2020-07-21",
#                     133
#                 ],
#                 [
#                     "2020-07-22",
#                     85
#                 ],
#                 [
#                     "2020-07-23",
#                     113
#                 ],
#                 [
#                     "2020-07-24",
#                     76
#                 ],
#                 [
#                     "2020-07-25",
#                     60
#                 ],
#                 [
#                     "2020-07-26",
#                     47
#                 ],
#                 [
#                     "2020-07-27",
#                     54
#                 ],
#                 [
#                     "2020-07-28",
#                     65
#                 ],
#                 [
#                     "2020-07-29",
#                     76
#                 ],
#                 [
#                     "2020-07-30",
#                     37
#                 ],
#                 [
#                     "2020-07-31",
#                     102
#                 ],
#                 [
#                     "2020-08-01",
#                     94
#                 ],
#                 [
#                     "2020-08-02",
#                     61
#                 ],
#                 [
#                     "2020-08-03",
#                     119
#                 ],
#                 [
#                     "2020-08-04",
#                     75
#                 ],
#                 [
#                     "2020-08-05",
#                     109
#                 ],
#                 [
#                     "2020-08-06",
#                     136
#                 ],
#                 [
#                     "2020-08-07",
#                     166
#                 ],
#                 [
#                     "2020-08-08",
#                     109
#                 ],
#                 [
#                     "2020-08-09",
#                     81
#                 ],
#                 [
#                     "2020-08-10",
#                     118
#                 ],
#                 [
#                     "2020-08-11",
#                     142
#                 ],
#                 [
#                     "2020-08-12",
#                     108
#                 ],
#                 [
#                     "2020-08-13",
#                     118
#                 ],
#                 [
#                     "2020-08-14",
#                     102
#                 ],
#                 [
#                     "2020-08-15",
#                     130
#                 ],
#                 [
#                     "2020-08-16",
#                     126
#                 ],
#                 [
#                     "2020-08-17",
#                     125
#                 ],
#                 [
#                     "2020-08-18",
#                     177
#                 ],
#                 [
#                     "2020-08-19",
#                     137
#                 ],
#                 [
#                     "2020-08-20",
#                     174
#                 ],
#                 [
#                     "2020-08-21",
#                     137
#                 ],
#                 [
#                     "2020-08-22",
#                     101
#                 ],
#                 [
#                     "2020-08-23",
#                     59
#                 ],
#                 [
#                     "2020-08-24",
#                     91
#                 ],
#                 [
#                     "2020-08-25",
#                     115
#                 ],
#                 [
#                     "2020-08-26",
#                     88
#                 ],
#                 [
#                     "2020-08-27",
#                     108
#                 ],
#                 [
#                     "2020-08-28",
#                     35
#                 ],
#                 [
#                     "2020-08-29",
#                     53
#                 ],
#                 [
#                     "2020-08-30",
#                     51
#                 ],
#                 [
#                     "2020-08-31",
#                     103
#                 ],
#                 [
#                     "2020-09-01",
#                     99
#                 ],
#                 [
#                     "2020-09-02",
#                     133
#                 ],
#                 [
#                     "2020-09-03",
#                     147
#                 ],
#                 [
#                     "2020-09-04",
#                     193
#                 ],
#                 [
#                     "2020-09-05",
#                     87
#                 ],
#                 [
#                     "2020-09-06",
#                     61
#                 ],
#                 [
#                     "2020-09-07",
#                     141
#                 ],
#                 [
#                     "2020-09-08",
#                     150
#                 ],
#                 [
#                     "2020-09-09",
#                     153
#                 ],
#                 [
#                     "2020-09-10",
#                     203
#                 ],
#                 [
#                     "2020-09-11",
#                     251
#                 ],
#                 [
#                     "2020-09-12",
#                     96
#                 ],
#                 [
#                     "2020-09-13",
#                     135
#                 ],
#                 [
#                     "2020-09-14",
#                     242
#                 ],
#                 [
#                     "2020-09-15",
#                     211
#                 ],
#                 [
#                     "2020-09-16",
#                     237
#                 ],
#                 [
#                     "2020-09-17",
#                     272
#                 ],
#                 [
#                     "2020-09-18",
#                     321
#                 ],
#                 [
#                     "2020-09-19",
#                     150
#                 ],
#                 [
#                     "2020-09-20",
#                     110
#                 ],
#                 [
#                     "2020-09-21",
#                     282
#                 ],

# %% [markdown]
# ## 答题数据、 互批2020-8-31

# %% [markdown]
# ### 答题卡数据使用分析

# %%
task13_taacher_sql = '''
        SELECT sc.school_id,sc.name ,sc.teacher_name,sc.grade_name ,sc.subject_name ,COUNT(DISTINCT task_id) as task_count ,hp.hp_count 
        from school_course_task sc LEFT JOIN 
        (SELECT sc.school_id,sc.name ,sc.teacher_name,sc.grade_name ,sc.subject_name ,COUNT(DISTINCT task_id) as hp_count from school_course_task sc WHERE sc.task_type = 13 and sc.correct_model = 1
         GROUP BY sc.school_id,sc.c_user_id 
        )hp  on hp.school_id = sc.school_id and sc.teacher_name = hp.teacher_name 
        WHERE sc.task_type = 13 
        GROUP BY sc.school_id,sc.c_user_id 
        ORDER BY COUNT(DISTINCT sc.task_id) DESC

'''
task13_taacher_count = sqliteDB(task13_taacher_sql)


task13_grade_sql = '''
        SELECT grade_name,count(DISTINCT task_id) from school_course_task where task_type = 13
        GROUP BY grade_name 
        ORDER BY count(DISTINCT task_id) DESC

'''
task13_grade_count = sqliteDB(task13_grade_sql)


task13_subject_sql = '''
        SELECT subject_name,count(DISTINCT task_id) from school_course_task where task_type = 13
        GROUP BY subject_name 
        ORDER BY count(DISTINCT task_id) DESC

'''
task13_subject_count = sqliteDB(task13_subject_sql)

# %%
task13_taacher_count['school_id'] = task13_taacher_count['school_id'].astype('str')
task13_taacher_count = task13_taacher_count.fillna(0)
task13_taacher_count.describe()
# Out:
#        task_count  hp_count
# count      3725.0    3725.0
# mean         11.0       0.5
# std          17.6       2.5
# min           1.0       0.0
# 25%           1.0       0.0
# 50%           4.0       0.0
# 75%          13.0       0.0
# max         187.0      75.0

# %%
task13_taacher_count.sort_values(axis = 0 ,by = 'task_count',ascending = False).reset_index(drop = True)
# Out:
#       school_id                    name teacher_name grade_name subject_name  \
# 0         53209          山东莱山第一中学(2020)          胡绍队       高二年级           数学
# 1         51585                  廊坊第一中学          杜艳波       高三年级           数学
# 2         51303                山东省烟台十四中          马小杰       高三年级           英语
# 3     100000589         烟台福山崇文中学(2020B)           钱芳       初一年级           英语
# 4         52923            重庆市彭水县思源实验学校          罗晓欢       初三年级           英语
# 5     100000589         烟台福山崇文中学(2020B)          巴信妞       初一年级           英语
# 6         51303                山东省烟台十四中        十四中初中       初一年级           英语
# 7     100000589         烟台福山崇文中学(2020B)          张予宣       初一年级           英语
# 8         53513               山东省牟平第一中学          杨富芝       高三年级           生物
# 9         52811               广西柳州市德润中学         英语资料       初一年级           英语
# 10        53394                 山东省招远一中          李少娟       高三年级           英语
# 11        53195                石家庄市同文中学           孙燕       初三年级           英语
# 12        51992             烟台赫尔曼格迈纳尔中学          陈维淑       初一年级           数学
# 13        53105              贵州省兴义市兴义中学           杨柳       高一年级           英语
# 14        53195                石家庄市同文中学          聂丽娟       初三年级           英语
# 15        51271               成都新都区第二中学           周芳       高一年级           英语
# 16        52923            重庆市彭水县思源实验学校          周淑贞       初三年级           英语
# 17        51271               成都新都区第二中学          何长贵       高二年级           物理
# 18        53006              四川省德阳市第三中学           陈明       高三年级           政治
# 19        52603             河北省秦皇岛市第一中学          刘冬梅       高三年级           历史
# 20        52811               广西柳州市德润中学         语文资料       初一年级           语文
# 21        52811               广西柳州市德润中学           邱海       初三年级           物理
# 22        50043                 大连分校910       郭郭教师dl       初二年级           语文
# 23        51147              广西省柳州市第八中学          韦柳青       初一年级           语文
# 24    100001194                 蓬莱市实验中学          曲祥艳      小学六年级           语文
# 25        51271               成都新都区第二中学           高婷       高二年级           英语
# 26        53209          山东莱山第一中学(2020)           赵双       高三年级           地理
# 27        51275                 四川都江堰中学          杨言美       高二年级           数学
# 3696           1       0.0
# 3697           1       0.0
# 3698           1       0.0
# 3699           1       0.0
# 3700           1       0.0
# 3701           1       0.0
# 3702           1       1.0
# 3703           1       0.0
# 3704           1       0.0
# 3705           1       0.0
# 3706           1       0.0
# 3707           1       0.0
# 3708           1       0.0
# 3709           1       0.0
# 3710           1       0.0
# 3711           1       0.0
# 3712           1       0.0
# 3713           1       0.0
# 3714           1       0.0
# 3715           1       0.0
# 3716           1       0.0
# 3717           1       0.0
# 3718           1       1.0
# 3719           1       0.0
# 3720           1       0.0
# 3721           1       0.0
# 3722           1       0.0
# 3723           1       0.0
# 3724           1       0.0

# %%
# hp_data = hptask_13_count['c_time'].groupby(hptask_13_count['c_time'].dt.date).agg('count')

task13_taacher_count.groupby(task13_taacher_count['grade_name']).agg('sum')['task_count']
# Out:
# grade_name
# 初一年级     6559
# 初三年级     3906
# 初二年级     4706
# 小学三年级       2
# 小学五年级       3
# 小学六年级    2453
# 小学四年级       1
# 高一年级     8798
# 高三年级     7153
# 高二年级     7420
# Name: task_count, dtype: int64

# %%
task13_grade_count
# Out:
#   grade_name  count(DISTINCT task_id)
# 0       高一年级                     8743
# 1       高二年级                     7416
# 2       高三年级                     7158
# 3       初一年级                     6214
# 4       初二年级                     4816
# 5       初三年级                     4100
# 6      小学六年级                     2547
# 7      小学五年级                        4
# 8      小学三年级                        2
# 9      小学四年级                        1

# %%
task13_grade_count.to_dict('records')
# Out:
# [{'grade_name': '高一年级', 'count(DISTINCT task_id)': 8743},
#  {'grade_name': '高二年级', 'count(DISTINCT task_id)': 7416},
#  {'grade_name': '高三年级', 'count(DISTINCT task_id)': 7158},
#  {'grade_name': '初一年级', 'count(DISTINCT task_id)': 6214},
#  {'grade_name': '初二年级', 'count(DISTINCT task_id)': 4816},
#  {'grade_name': '初三年级', 'count(DISTINCT task_id)': 4100},
#  {'grade_name': '小学六年级', 'count(DISTINCT task_id)': 2547},
#  {'grade_name': '小学五年级', 'count(DISTINCT task_id)': 4},
#  {'grade_name': '小学三年级', 'count(DISTINCT task_id)': 2},
#  {'grade_name': '小学四年级', 'count(DISTINCT task_id)': 1}]

# %%
task13_subject_count
# Out:
#    subject_name  count(DISTINCT task_id)
# 0            英语                    12387
# 1            数学                     6544
# 2            语文                     4793
# 3            生物                     3537
# 4            物理                     3343
# 5            化学                     3192
# 6            历史                     2424
# 7            地理                     2401
# 8            政治                     2228
# 9            其他                      105
# 10           科学                       47

# %% [markdown]
# ### 学校的答题卡使用情况

# %%
task13_sql = '''
       
        SELECT a.school_id,a.name,b.task13_count,c.hp_task13_count
        FROM "school_course_task" a  LEFT JOIN  (SELECT school_id ,count(DISTINCT task_id) as task13_count from school_course_task where task_type = 13  GROUP BY school_id) b  on a.school_id = b.school_id
        LEFT JOIN (SELECT school_id ,count(DISTINCT task_id) as hp_task13_count from school_course_task where  correct_model != 0  GROUP BY school_id) c on a.school_id = c.school_id
        GROUP BY a.school_id

        '''
task_13_count = sqliteDB(task13_sql)

# %%
task_13_count = task_13_count.fillna(0)
# 544      53758                   蒙泉镇夏家巷中学           0.0              0.0
# 545      53757                    蒙泉镇中心学校           0.0              0.0
# 546      53756                    新关镇中心学校           1.0              0.0
# 547      53754                     湖南澧斓中学           0.0              0.0
# 548      53753                   宝峰街道中心学校           0.0              0.0
# 549      53891                湖南武冈市思源实验学校           1.0              0.0
# 550      53892                 邢台市广宗县葫芦中学           6.0              0.0
# 551      53895                    南阳市智慧课堂           0.0              0.0
# 552      53896                   南阳市三中南院区           0.0              0.0
# 553      54052                华罗庚实验学校西宁学校           0.0              0.0
# 554      54051                西宁市总寨镇逯家寨学校           0.0              0.0
# 555      54049                 西宁市城北区山川学校           0.0              0.0
# 556      54048                 西宁市城北区朝阳学校           0.0              0.0
# 557      54047                    西宁市七一中学           4.0              0.0
# 558      54045                    西宁市第五中学           3.0              0.0
# 559      54044                    西宁市第八中学           0.0              0.0
# 560      54043                  西宁市体育实验中学           0.0              0.0
# 561      54042                  西宁市艺术实验中学           0.0              0.0
# 562      54041                    西宁市总寨中学           4.0              0.0
# 563      54040                  西宁市第二十八中学           0.0              0.0
# 564      54039                    西宁市回族中学           0.0              0.0
# 565      54037                  西宁市第二十一中学           0.0              0.0
# 566      54036                    西宁市五一学校           0.0              0.0
# 567      54035                    西宁市第十中学           0.0              0.0
# 568      54033                     青海湟川中学           0.0              0.0
# 569      54019               四川省剑阁县武连职业中学           0.0              0.0
# 570      54015                   天津英华国际学校           0.0              0.0
# 571      54013                  广元剑阁县白龙中学           6.0              0.0
# 572      54009                     江苏苏州中学           0.0              0.0
# 573      54006                  贵州都匀市江洲中学           0.0              0.0
# 574      54004               海南临高第二思源实验学校           3.0              0.0
# 575      53998     海南华侨中学观澜湖电影公社校区(2020B)          14.0              0.0
# 576      53948                 甘肃省榆中县第一中学           0.0              0.0
# 577      53943                 湖南桑植思源实验学校           0.0              0.0
# 578      53926                     洛阳实验中学           0.0              0.0
# 579      53902                 武汉市第十二初级中学           0.0              0.0
# 580  100002275                    兴义市阳光书院           0.0              0.0

# %% [markdown]
# ### 互批每天数据

# %%
hptask13_sql = '''
        SELECT school_id,name ,task_id,c_time   from school_course_task where  correct_model != 0  
        '''
hptask_13_count = sqliteDB(hptask13_sql)
# c_time专程 datatime 格式
hptask_13_count['c_time'] = pd.to_datetime(hptask_13_count['c_time'] )

# %%
hptask_13_count.head()
# Out:
#    school_id     name        task_id              c_time
# 0      50043  大连分校910 -6411823342999 2020-09-18 13:20:11
# 1      50043  大连分校910 -6411823342999 2020-09-18 13:20:11
# 2      50043  大连分校910 -6411823342999 2020-09-18 13:20:11
# 3      50043  大连分校910 -6411823342999 2020-09-18 13:20:11
# 4      50043  大连分校910 -6247932090937 2020-09-18 13:17:27

# %%
hp_data = hptask_13_count.drop_duplicates(['task_id'])['c_time'].groupby(hptask_13_count['c_time'].dt.date).agg('count')

# %%
hp_data_x = hp_data.index.tolist()
hp_data_y = hp_data.values.tolist()

# %%
#渲染图大小
line = Line(init_opts = opts.InitOpts(width = '1000px'))

#X轴数据
line.add_xaxis(hp_data_x)
#Y轴名称和
line.add_yaxis("答题卡互批", hp_data_y)

# 全局配置
line.set_global_opts(
    #主标题
    title_opts=opts.TitleOpts(title="答题卡互批"),
    # 缩放功能
    datazoom_opts = opts.DataZoomOpts( is_show = True , type_ ='slider',range_start = 50,range_end = 100),
    # x轴文字距离，旋转角度
    xaxis_opts=opts.AxisOpts(
            axislabel_opts={"interval":"0","rotate":45},
        ),
)

# 系统配置
line.set_series_opts(
    # 图中显示数值
    label_opts = opts.LabelOpts(is_show=True),


    # 线装图，平均线
    markline_opts=opts.MarkLineOpts(
        data=[opts.MarkLineItem(type_="average", name="平均值"),]
                                    ),
    # 点装图，最大值最小值
    markpoint_opts=opts.MarkPointOpts(
            data=[
                opts.MarkPointItem(type_="min", name="最小值"),
                opts.MarkPointItem(type_="max", name="最大值"),
            ]
        ),
)
line.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="89620d8c77504765931739813c7ec8c9" class="chart-container" style="width:1000px; height:500px;"></div>
#     <script>
#         var chart_89620d8c77504765931739813c7ec8c9 = echarts.init(
#             document.getElementById('89620d8c77504765931739813c7ec8c9'), 'white', {renderer: 'canvas'});
#         var option_89620d8c77504765931739813c7ec8c9 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u7b54\u9898\u5361\u4e92\u6279",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "2020-07-31",
#                     1
#                 ],
#                 [
#                     "2020-08-05",
#                     1
#                 ],
#                 [
#                     "2020-08-13",
#                     2
#                 ],
#                 [
#                     "2020-08-31",
#                     37
#                 ],
#                 [
#                     "2020-09-01",
#                     14
#                 ],
#                 [
#                     "2020-09-02",
#                     12
#                 ],
#                 [
#                     "2020-09-03",
#                     10
#                 ],
#                 [
#                     "2020-09-04",
#                     7
#                 ],
#                 [
#                     "2020-09-05",
#                     5
#                 ],
#                 [
#                     "2020-09-06",
#                     1
#                 ],
#                 [
#                     "2020-09-07",
#                     10
#                 ],
#                 [
#                     "2020-09-08",
#                     17
#                 ],
#                 [
#                     "2020-09-09",
#                     10
#                 ],
#                 [
#                     "2020-09-10",
#                     12
#                 ],
#                 [
#                     "2020-09-11",
#                     22
#                 ],
#                 [
#                     "2020-09-12",
#                     4
#                 ],
#                 [
#                     "2020-09-13",
#                     12
#                 ],
#                 [
#                     "2020-09-14",
#                     10
#                 ],
#                 [
#                     "2020-09-15",
#                     9
#                 ],
#                 [
#                     "2020-09-16",
#                     11
#                 ],
#                 [
#                     "2020-09-17",
#                     15
#                 ],
#                 [
#                     "2020-09-18",
#                     28
#                 ],
#                 [
#                     "2020-09-19",
#                     3
#                 ],
#                 [
#                     "2020-09-20",
#                     1
#                 ],
#                 [
#                     "2020-09-21",
#                     16
#                 ],
#                 [
#                     "2020-09-22",
#                     27
#                 ],
#                 [
#                     "2020-09-23",
#                     18
#                 ],
#                 [
#                     "2020-09-24",
#                     16
#                 ],
#                 [
#                     "2020-09-25",
#                     12
#                 ],
#                 [
#                     "2020-09-26",
#                     5
#                 ],
#                 [
#                     "2020-09-27",
#                     5
#                 ],
#                 [
#                     "2020-09-28",
#                     13
#                 ],
#                 [
#                     "2020-09-29",
#                     27
#                 ],
#                 [
#                     "2020-09-30",
#                     20
#                 ],
#                 [
#                     "2020-10-01",
#                     11
#                 ],
#                 [
#                     "2020-10-02",
#                     14
#                 ],
#                 [
#                     "2020-10-03",
#                     9
#                 ],
#                 [
#                     "2020-10-04",
#                     7
#                 ],
#                 [
#                     "2020-10-05",
#                     4
#                 ],
#                 [
#                     "2020-10-06",
#                     2
#                 ],
#                 [
#                     "2020-10-07",
#                     1
#                 ],
#                 [
#                     "2020-10-08",
#                     4
#                 ],
#                 [
#                     "2020-10-09",
#                     8
#                 ],
#                 [
#                     "2020-10-10",
#                     10
#                 ],
#                 [
#                     "2020-10-11",
#                     4
#                 ],
#                 [
#                     "2020-10-12",
#                     20
#                 ],
#                 [
#                     "2020-10-13",
#                     12
#                 ],
#                 [
#                     "2020-10-14",
#                     16
#                 ],
#                 [
#                     "2020-10-15",
#                     13
#                 ],
#                 [
#                     "2020-10-16",
#                     18
#                 ],
#                 [
#                     "2020-10-17",
#                     10
#                 ],
#                 [
#                     "2020-10-18",
#                     4
#                 ],
#                 [
#                     "2020-10-19",
#                     28
#                 ],
#                 [
#                     "2020-10-20",
#                     20
#                 ],
#                 [
#                     "2020-10-21",
#                     19
#                 ],
#                 [
#                     "2020-10-22",
#                     19
#                 ],
#                 [
#                     "2020-10-23",
#                     21
#                 ],
#                 [
#                     "2020-10-24",
#                     8
#                 ],
#                 [
#                     "2020-10-25",
#                     9
#                 ],
#                 [
#                     "2020-10-26",
#                     36
#                 ],
#                 [
#                     "2020-10-27",
#                     24
#                 ],
#                 [
#                     "2020-10-28",
#                     23
#                 ],
#                 [
#                     "2020-10-29",
#                     21
#                 ],
#                 [
#                     "2020-10-30",
#                     36
#                 ],
#                 [
#                     "2020-10-31",
#                     5
#                 ],
#                 [
#                     "2020-11-01",
#                     11
#                 ],
#                 [
#                     "2020-11-02",
#                     43
#                 ],
#                 [
#                     "2020-11-03",
#                     20
#                 ],
#                 [
#                     "2020-11-04",
#                     36
#                 ],
#                 [
#                     "2020-11-05",

# %% [markdown]
# ### 答题卡数据每周变化

# %%
task_13_0911 = school_course_task.drop_duplicates(['task_id']).loc[(school_course_task['task_type']== 13) & (school_course_task['c_time']<= '2020-09-11 23:59:59')]
task_13_0918 = school_course_task.drop_duplicates(['task_id']).loc[(school_course_task['task_type']== 13) & (school_course_task['c_time']<= '2020-09-18 23:59:59')]
task_13_0925 = school_course_task.drop_duplicates(['task_id']).loc[(school_course_task['task_type']== 13) & (school_course_task['c_time']<= '2020-09-25 23:59:59')]
task_13_1009 = school_course_task.drop_duplicates(['task_id']).loc[(school_course_task['task_type']== 13) & (school_course_task['c_time']<= '2020-10-09 23:59:59')]
task_13_1016 = school_course_task.drop_duplicates(['task_id']).loc[(school_course_task['task_type']== 13) & (school_course_task['c_time']<= '2020-10-16 23:59:59')]
task_13_1023 = school_course_task.drop_duplicates(['task_id']).loc[(school_course_task['task_type']== 13) & (school_course_task['c_time']<= '2020-10-23 23:59:59')]
task_13_1030 = school_course_task.drop_duplicates(['task_id']).loc[(school_course_task['task_type']== 13) & (school_course_task['c_time']<= '2020-10-30 23:59:59')]


task_13hp_0911 = school_course_task.drop_duplicates(['task_id']).loc[(school_course_task['task_type']== 13) & (school_course_task['c_time']<= '2020-09-11 23:59:59')&(school_course_task['correct_model']==1)]
task_13hp_0918 = school_course_task.drop_duplicates(['task_id']).loc[(school_course_task['task_type']== 13) & (school_course_task['c_time']<= '2020-09-18 23:59:59')&(school_course_task['correct_model']==1)]
task_13hp_0925 = school_course_task.drop_duplicates(['task_id']).loc[(school_course_task['task_type']== 13) & (school_course_task['c_time']<= '2020-09-25 23:59:59')&(school_course_task['correct_model']==1)]
task_13hp_1009 = school_course_task.drop_duplicates(['task_id']).loc[(school_course_task['task_type']== 13) & (school_course_task['c_time']<= '2020-10-09 23:59:59')&(school_course_task['correct_model']==1)]
task_13hp_1016 = school_course_task.drop_duplicates(['task_id']).loc[(school_course_task['task_type']== 13) & (school_course_task['c_time']<= '2020-10-16 23:59:59')&(school_course_task['correct_model']==1)]
task_13hp_1023 = school_course_task.drop_duplicates(['task_id']).loc[(school_course_task['task_type']== 13) & (school_course_task['c_time']<= '2020-10-23 23:59:59')&(school_course_task['correct_model']==1)]
task_13hp_1030 = school_course_task.drop_duplicates(['task_id']).loc[(school_course_task['task_type']== 13) & (school_course_task['c_time']<= '2020-10-30 23:59:59')&(school_course_task['correct_model']==1)]

# %%
from pyecharts.charts import Bar
from pyecharts import options as opts
  
x_timedata = [ '7月15日至09月11','7月15日至09月18','7月15日至09月25','7月15日至10月09','7月15日至10月16','7月15日至10月23','7月15日至10月30' ]


task_13_school = [ 
    int(task_13_0911.drop_duplicates(subset = ['school_id'],keep = 'first').agg('count')['school_id']),
    int(task_13_0918.drop_duplicates(subset = ['school_id'],keep = 'first').agg('count')['school_id']),
    int(task_13_0925.drop_duplicates(subset = ['school_id'],keep = 'first').agg('count')['school_id']),
    int(task_13_1009.drop_duplicates(subset = ['school_id'],keep = 'first').agg('count')['school_id']),
    int(task_13_1016.drop_duplicates(subset = ['school_id'],keep = 'first').agg('count')['school_id']),   
    int(task_13_1023.drop_duplicates(subset = ['school_id'],keep = 'first').agg('count')['school_id']),   
    int(task_13_1030.drop_duplicates(subset = ['school_id'],keep = 'first').agg('count')['school_id']),   

     ]
task_13hp_school= [
    int(task_13hp_0911.drop_duplicates(subset = ['school_id'],keep = 'first').agg('count')['school_id']),
    int(task_13hp_0918.drop_duplicates(subset = ['school_id'],keep = 'first').agg('count')['school_id']),
    int(task_13hp_0925.drop_duplicates(subset = ['school_id'],keep = 'first').agg('count')['school_id']),
    int(task_13hp_1009.drop_duplicates(subset = ['school_id'],keep = 'first').agg('count')['school_id']),
    int(task_13hp_1016.drop_duplicates(subset = ['school_id'],keep = 'first').agg('count')['school_id']),
    int(task_13hp_1023.drop_duplicates(subset = ['school_id'],keep = 'first').agg('count')['school_id']),
    int(task_13hp_1030.drop_duplicates(subset = ['school_id'],keep = 'first').agg('count')['school_id']),

]
task_13_count= [
    int(task_13_0911.agg('count')['task_id']),
    int(task_13_0918.agg('count')['task_id']),
    int(task_13_0925.agg('count')['task_id']),
    int(task_13_1009.agg('count')['task_id']),
    int(task_13_1016.agg('count')['task_id']),
    int(task_13_1023.agg('count')['task_id']),
    int(task_13_1030.agg('count')['task_id']),


]

task_13hp_count= [
    int(task_13hp_0911.agg('count')['task_id']),
    int(task_13hp_0918.agg('count')['task_id']),
    int(task_13hp_0925.agg('count')['task_id']),
    int(task_13hp_1009.agg('count')['task_id']),
    int(task_13hp_1016.agg('count')['task_id']),
    int(task_13hp_1023.agg('count')['task_id']),
    int(task_13hp_1030.agg('count')['task_id']),

]


bar = Bar()
#设置x轴
bar.add_xaxis(xaxis_data=x_timedata)
bar .set_global_opts(xaxis_opts=opts.AxisOpts(axislabel_opts={"rotate":25}))



#设置y轴

bar.add_yaxis(series_name='使用答题卡学校数量',y_axis=task_13_school)
bar.add_yaxis(series_name='使用互批学校数量',y_axis=task_13hp_school)
bar.add_yaxis(series_name='答题卡数量',y_axis=task_13_count)
bar.add_yaxis(series_name='答题卡设置互批总数',y_axis=task_13hp_count)


  
bar.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="ad072b2d6ef0448196d8d2fddd3e52ef" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_ad072b2d6ef0448196d8d2fddd3e52ef = echarts.init(
#             document.getElementById('ad072b2d6ef0448196d8d2fddd3e52ef'), 'white', {renderer: 'canvas'});
#         var option_ad072b2d6ef0448196d8d2fddd3e52ef = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u4f7f\u7528\u7b54\u9898\u5361\u5b66\u6821\u6570\u91cf",
#             "legendHoverLink": true,
#             "data": [
#                 142,
#                 170,
#                 187,
#                 194,
#                 205,
#                 214,
#                 218
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u4f7f\u7528\u4e92\u6279\u5b66\u6821\u6570\u91cf",
#             "legendHoverLink": true,
#             "data": [
#                 37,
#                 50,
#                 57,
#                 73,
#                 81,
#                 90,
#                 95
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u7b54\u9898\u5361\u6570\u91cf",
#             "legendHoverLink": true,
#             "data": [
#                 6529,
#                 8043,
#                 9848,
#                 12686,
#                 14655,
#                 16710,
#                 19268
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u7b54\u9898\u5361\u8bbe\u7f6e\u4e92\u6279\u603b\u6570",
#             "legendHoverLink": true,
#             "data": [
#                 161,
#                 250,
#                 343,
#                 473,
#                 566,
#                 687,
#                 844
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u4f7f\u7528\u7b54\u9898\u5361\u5b66\u6821\u6570\u91cf",
#                 "\u4f7f\u7528\u4e92\u6279\u5b66\u6821\u6570\u91cf",
#                 "\u7b54\u9898\u5361\u6570\u91cf",
#                 "\u7b54\u9898\u5361\u8bbe\u7f6e\u4e92\u6279\u603b\u6570"
#             ],
#             "selected": {
#                 "\u4f7f\u7528\u7b54\u9898\u5361\u5b66\u6821\u6570\u91cf": true,
#                 "\u4f7f\u7528\u4e92\u6279\u5b66\u6821\u6570\u91cf": true,
#                 "\u7b54\u9898\u5361\u6570\u91cf": true,
#                 "\u7b54\u9898\u5361\u8bbe\u7f6e\u4e92\u6279\u603b\u6570": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "rotate": 25
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "7\u670815\u65e5\u81f309\u670811",
#                 "7\u670815\u65e5\u81f309\u670818",
#                 "7\u670815\u65e5\u81f309\u670825",
#                 "7\u670815\u65e5\u81f310\u670809",
#                 "7\u670815\u65e5\u81f310\u670816",
#                 "7\u670815\u65e5\u81f310\u670823",
#                 "7\u670815\u65e5\u81f310\u670830"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#         chart_ad072b2d6ef0448196d8d2fddd3e52ef.setOption(option_ad072b2d6ef0448196d8d2fddd3e52ef);
#     </script>
# </body>
# </html>

# %%
# 使用答题卡学校数量

print('7月15日至09月11 使用答题卡学校数量：',task_13_0911.drop_duplicates(subset = ['school_id'],keep = 'first').agg('count')['school_id'])
print('7月15日至09月18 使用答题卡学校数量：',task_13_0918.drop_duplicates(subset = ['school_id'],keep = 'first').agg('count')['school_id'])
print('7月15日至09月25 使用答题卡学校数量：',task_13_0925.drop_duplicates(subset = ['school_id'],keep = 'first').agg('count')['school_id'])
print('7月15日至10月09 使用答题卡学校数量：',task_13_1009.drop_duplicates(subset = ['school_id'],keep = 'first').agg('count')['school_id'])
print('7月15日至10月16 使用答题卡学校数量：',task_13_1016.drop_duplicates(subset = ['school_id'],keep = 'first').agg('count')['school_id'])
print('7月15日至10月23 使用答题卡学校数量：',task_13_1023.drop_duplicates(subset = ['school_id'],keep = 'first').agg('count')['school_id'])
print('7月15日至10月30 使用答题卡学校数量：',task_13_1030.drop_duplicates(subset = ['school_id'],keep = 'first').agg('count')['school_id'])


print('--------------------------')

#使用互批学校数量
# print('8月31日至今使用互批学校数量：{}'.format(task_13_count[task_13_count['hp_task13_count']>0].count()['name']))
print('7月15日至09月11 使用互批学校数量：',task_13hp_0911.drop_duplicates(subset = ['school_id'],keep = 'first').agg('count')['school_id'])
print('7月15日至09月18 使用互批学校数量：',task_13hp_0918.drop_duplicates(subset = ['school_id'],keep = 'first').agg('count')['school_id'])
print('7月15日至09月25 使用互批学校数量：',task_13hp_0925.drop_duplicates(subset = ['school_id'],keep = 'first').agg('count')['school_id'])
print('7月15日至10月09 使用互批学校数量：',task_13hp_1009.drop_duplicates(subset = ['school_id'],keep = 'first').agg('count')['school_id'])
print('7月15日至10月16 使用互批学校数量：',task_13hp_1016.drop_duplicates(subset = ['school_id'],keep = 'first').agg('count')['school_id'])
print('7月15日至10月23 使用互批学校数量：',task_13hp_1023.drop_duplicates(subset = ['school_id'],keep = 'first').agg('count')['school_id'])
print('7月15日至10月30 使用互批学校数量：',task_13hp_1030.drop_duplicates(subset = ['school_id'],keep = 'first').agg('count')['school_id'])

print('--------------------------')


#答题卡数量
# print('7月15日至今答题卡数量：{}'.format(task_13_count['task13_count'].sum(axis = 0)))
print('7月15日至09月11 答题卡数量：',task_13_0911.agg('count')['task_id'])
print('7月15日至09月18 答题卡数量：',task_13_0918.agg('count')['task_id'])
print('7月15日至09月25 答题卡数量：',task_13_0925.agg('count')['task_id'])
print('7月15日至10月09 答题卡数量：',task_13_1009.agg('count')['task_id'])
print('7月15日至10月16 答题卡数量：',task_13_1016.agg('count')['task_id'])
print('7月15日至10月23 答题卡数量：',task_13_1023.agg('count')['task_id'])
print('7月15日至10月30 答题卡数量：',task_13_1030.agg('count')['task_id'])

print('--------------------------')

#答题卡设置互批总数
# print('8月31日至今答题卡设置互批总数：{}'.format(task_13_count['hp_task13_count'].sum(axis = 0)))
print('7月15日至09月11 答题卡设置互批总数：',task_13hp_0911.agg('count')['task_id'])
print('7月15日至09月18 答题卡设置互批总数：',task_13hp_0918.agg('count')['task_id'])
print('7月15日至09月25 答题卡设置互批总数：',task_13hp_0925.agg('count')['task_id'])
print('7月15日至10月09 答题卡设置互批总数：',task_13hp_1009.agg('count')['task_id'])
print('7月15日至10月16 答题卡设置互批总数：',task_13hp_1016.agg('count')['task_id'])
print('7月15日至10月23 答题卡设置互批总数：',task_13hp_1023.agg('count')['task_id'])
print('7月15日至10月30 答题卡设置互批总数：',task_13hp_1030.agg('count')['task_id'])
# Out:
# 7月15日至09月11 使用答题卡学校数量： 142
# 7月15日至09月18 使用答题卡学校数量： 170
# 7月15日至09月25 使用答题卡学校数量： 187
# 7月15日至10月09 使用答题卡学校数量： 194
# 7月15日至10月16 使用答题卡学校数量： 205
# 7月15日至10月23 使用答题卡学校数量： 214
# 7月15日至10月30 使用答题卡学校数量： 218
# --------------------------
# 7月15日至09月11 使用互批学校数量： 37
# 7月15日至09月18 使用互批学校数量： 50
# 7月15日至09月25 使用互批学校数量： 57
# 7月15日至10月09 使用互批学校数量： 73
# 7月15日至10月16 使用互批学校数量： 81
# 7月15日至10月23 使用互批学校数量： 90
# 7月15日至10月30 使用互批学校数量： 95
# --------------------------
# 7月15日至09月11 答题卡数量： 6529
# 7月15日至09月18 答题卡数量： 8043
# 7月15日至09月25 答题卡数量： 9848
# 7月15日至10月09 答题卡数量： 12686
# 7月15日至10月16 答题卡数量： 14655
# 7月15日至10月23 答题卡数量： 16710
# 7月15日至10月30 答题卡数量： 19268
# --------------------------
# 7月15日至09月11 答题卡设置互批总数： 161
# 7月15日至09月18 答题卡设置互批总数： 250
# 7月15日至09月25 答题卡设置互批总数： 343
# 7月15日至10月09 答题卡设置互批总数： 473
# 7月15日至10月16 答题卡设置互批总数： 566
# 7月15日至10月23 答题卡设置互批总数： 687
# 7月15日至10月30 答题卡设置互批总数： 844

# %% [markdown]
# # 爱学派班级数据

# %%
axp_class_sql = ('''
    SELECT fr.school_id,fr.name , count(c.class_id)  as '爱学派班级数'
    from  class_info c, franchised_school_info fr  
    where c.axp_end_time >NOW()  and fr.school_type in (3,4) and fr.school_id =c.DC_SCHOOL_ID  and c.year = '2020~2021'
    group by  fr.name
    ORDER by '爱学派班级数' DESC
         ''')
axp_class = mysqlDB(axp_class_sql)

# %%
axp_class.sort_values(ascending = False ,by = '爱学派班级数' , axis = 0 )
# Out:
#      school_id                    name  爱学派班级数
# 80       52923            重庆市彭水县思源实验学校      60
# 141      53950              贵州省兴义市兴义四中      59
# 69       53104              贵州省兴义市兴义三中      55
# 210  100002131               天门市杭州华泰中学      54
# 9        53209          山东莱山第一中学(2020)      51
# 50       52603             河北省秦皇岛市第一中学      50
# 173      53827            湖南省安化县思源实验学校      46
# 4        50083             成都市龙泉驿区第一中学      42
# 31       53513               山东省牟平第一中学      41
# 1        50043                 大连分校910      40
# 59       53195                石家庄市同文中学      39
# 52       51380                 大连市红旗高中      38
# 48       51303                山东省烟台十四中      37
# 125      54202                山东济宁东方中学      37
# 114      53206              湖北省恩施市英才学校      35
# 17       51899                山东烟台港城中学      33
# 170  100000927               西畴县思源实验学校      27
# 5        51271               成都新都区第二中学      27
# 174      54004            海南临高第二思源实验学校      27
# 261  100001702               江永县思源实验学校      26
# 168  100000605                海南文昌联东中学      25
# 84       53831              重庆市彭水汉葭镇中学      23
# 117      51275                 四川都江堰中学      22
# 81       53394                 山东省招远一中      22
# 197      53105              贵州省兴义市兴义中学      21
# 18       51992             烟台赫尔曼格迈纳尔中学      21
# 167      53889            湖南省新晃县思源实验学校      21
# 41       51057              宁夏石嘴山市第二中学      20
# 35       53095                湖南石门思源学校      20
# 178      53006              四川省德阳市第三中学      20
# 43       53362               烟台市栖霞第一中学      19
# 177  100000509               东莞市沙田实验中学      19
# 133  100000589         烟台福山崇文中学(2020B)      18
# 211  100001922          栖霞市第二中学(停课不停学)       1
# 182  100001022                 栖霞市庙后中学       1
# 183      53359                 钦州市第三中学       1
# 207  100002127               柳州市第二十五中学       1
# 214  100001194                 蓬莱市实验中学       1
# 140  100000617                石嘴山市丽日中学       1
# 221  100001243         招远市魁星路中学(停课不停学)       1
# 223  100000664           江苏省淮安市涟水县唐集学校       1
# 224  100001947                 招远市金晖学校       1
# 225      51336              江西省赣州市章贡中学       1
# 71       52731              宁夏石嘴山市第九中学       1
# 53       53607                  运城闻喜二中       1
# 122  100000315                东莞塘厦初级中学       1
# 75       53826                  德阳第七中学       1
# 193      51585                  廊坊第一中学       1
# 236  100000921                    新城中学       1
# 189  100002104                    饶安中学       1
# 209  100001824                栖霞市唐家泊中学       1
# 241  100002111           新疆乌鲁木齐南山县第一中学       1
# 186  100002097           山东青岛崂山黄岛分中心演示       1
# 185  100000920                    河田中学       1
# 184  100000893          乐亭县姜各庄镇姜各庄初级中学       1
# 268  100002275                 兴义市阳光书院       1

# %% [markdown]
# ## 有效爱学派班级总数

# %%
print('有效爱学派班级总数：',axp_class['爱学派班级数'].sum())
# Out:
# 有效爱学派班级总数： 2122

# %% [markdown]
# # 口语先声开通数据

# %%
english_sql = ('''
     SELECT fr.school_id,fr.name ,count(DISTINCT a.user_id) as '先声学生有效人数',t.tea_count as '教师开通人数'
     FROM sing_sound_user_auth_config_info a,franchised_school_info fr ,(select school_id ,count(DISTINCT(user_id) ) as tea_count from teaching_j_user_module where object_type_id = 2 
     GROUP BY school_id ) t
     WHERE  a.end_time > a.c_time  AND a.school_id=fr.school_id and a.end_time >NOW()  and t.school_id = fr.school_id and fr.school_type in (3,4) and fr.school_id >50000 and fr.enable = 0
     GROUP BY a.school_id
         ''')
english_count = mysqlDB(english_sql)

# %%
english_count
# Out:
#     school_id           name  先声学生有效人数  教师开通人数
# 0       50043        大连分校910        43      26
# 1       51036     湖南省怀化市宏宇中学       542      24
# 2       51057     宁夏石嘴山市第二中学      1049      14
# 3       51147     广西省柳州市第八中学       272       5
# 4       51286           北京四中      4068      54
# 5       51572        北京市第七中学        98       8
# 6       52811      广西柳州市德润中学       488      26
# 7       52923   重庆市彭水县思源实验学校      3149      35
# 8       53104     贵州省兴义市兴义三中       688       1
# 9       53105     贵州省兴义市兴义中学      2427      13
# 10      53202       石嘴山市第一中学       307      22
# 11      53205       石嘴山市实验中学       190       2
# 12      53670      凉山州凉山俊波中学       212      72
# 13      53827   湖南省安化县思源实验学校      2769      30
# 14      54202       山东济宁东方中学      7650      33
# 15      54204        乐山市第五中学      1764      21
# 16  100000421       东莞大朗启明学校       254       8
# 17  100000605       海南文昌联东中学      1613      17
# 18  100001235        福泉市第二中学        72       3
# 19  100002021     贵州省兴义市兴义二中       783      10
# 20  100002106  兴义市民族师范学院附属中学       165       4
# 21  100002108   凉山州会理县民族实验中学       101       4
# 22  100002115        怀化市武陵中学       197       3
# 23  100002127      柳州市第二十五中学        44       2
# 24  100002136        庆云县第二中学       100       2
# 25  100002150        庆云县渤海中学       190       3
# 26  100002194        宝鸡十里铺中学        47       1
# 27  100002275        兴义市阳光书院         3       1

# %% [markdown]
# ## 口语先声开通人数

# %%
print('开通口语先声学生人数数：',english_count['先声学生有效人数'].sum())
print('开通口语先声总教师人数：',english_count['教师开通人数'].sum())
# Out:
# 开通口语先声学生人数数： 29285
# 开通口语先声总教师人数： 444

# %%
# school_count.columns.to_list()

school_describe = (course_file.iloc[:,5:]).describe()

school_dic = {
    '班级数':course_file['班级数'].sum( axis = 0),
     '教师人数':course_file['教师人数'].sum(),
     '学生人数':course_file['学生人数'].sum(),
     '爱学派班级数':course_file['爱学派班级数'].sum(),
     '课程数':course_file['课程数'].sum(),
     '学校任务总数':course_file['学校任务总数'].sum(),
     '学资源':course_file['学资源'].sum(),
     '讨论':course_file['讨论'].sum(),
     '单个试题':course_file['单个试题'].sum(),
     '测验':course_file['测验'].sum(),
     '微课':course_file['微课'].sum(),
     '一般任务（语音）':course_file['一般任务（语音）'].sum(),
     '一般任务（文字）':course_file['一般任务（文字）'].sum(),
     '一般任务（图片）':course_file['一般任务（图片）'].sum(),
     '直播课':course_file['直播课'].sum(),
     '答题卡':course_file['答题卡'].sum(),
     '个性化':course_file['个性化'].sum(),
     '先声':course_file['先声'].sum(),
     '先声学生有效人数':course_file['先声学生有效人数'].sum(axis = 0),
     '教师开通人数':course_file['教师开通人数'].sum(),
     '答题卡数量':course_file['答题卡数量'].sum(),
     '教师批改':course_file['教师批改'].sum(),
     '学生互批':course_file['学生互批'].sum()
}
school_df = pd.DataFrame(school_dic,index = ['sum'])
school_describe = school_describe.append(school_df)
school_describe
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-30e0f11695dd> in <module>
#       1 # school_count.columns.to_list()
#       2
# ----> 3 school_describe = (course_file.iloc[:,5:]).describe()
#       4
#       5 school_dic = {
#
# NameError: name 'course_file' is not defined

# %% [markdown]
# # 资源数据汇总下载

# %%
res_count

# %%
res_count.to_excel('../jupyter/resource/平台资源数据%s.xls'%now_time)
print('导出成功')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-4b7d1f8f15a4> in <module>
# ----> 1 res_count.to_excel('../jupyter/resource/平台资源数据%s.xls'%now_time)
#       2 print('导出成功')
#       3
#
# NameError: name 'res_count' is not defined

# %% [markdown]
# # 教师查询

# %% [markdown]
# ## 教师用户名查询

# %%
tea_name_sql = ('''
    SELECT s.name,s.school_id ,u.ETT_USER_ID,oc.user_name , oc.password,t.TEACHER_NAME ,u.state_id, c.CLASS_ID,c.CLASS_GRADE,c.CLASS_NAME,c.PATTERN,sb.SUBJECT_NAME,jc.C_TIME
    from  oracle2utf.coschuser_info oc,user_info u,school_info s,teacher_info t ,j_class_user jc ,class_info c,subject_info sb
    where  oc.jid = u.ETT_USER_ID and u.DC_SCHOOL_ID = s.school_id and u.ref = t.user_id  and u.ref = jc.user_id  and jc.CLASS_ID = c.CLASS_ID and c.`YEAR` = '2020~2021' and jc.SUBJECT_ID = sb.SUBJECT_ID
    and oc.user_name ='大连测试001' 
    GROUP BY s.school_id ,u.ETT_USER_ID,c.CLASS_GRADE,c.CLASS_NAME,sb.SUBJECT_NAME
         ''')
tea_name = mysqlDB(tea_name_sql)
tea_name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-1799adc6d91a> in <module>
#       6     GROUP BY s.school_id ,u.ETT_USER_ID,c.CLASS_GRADE,c.CLASS_NAME,sb.SUBJECT_NAME
#       7          ''')
# ----> 8 tea_name = mysqlDB(tea_name_sql)
#       9 tea_name
#
# NameError: name 'mysqlDB' is not defined

# %%
tea_name_json =  tea_name.to_dict('records')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-8ca360d0f592> in <module>
# ----> 1 tea_name_json =  tea_name.to_dict('records')
#
# NameError: name 'tea_name' is not defined

# %%
tea_name_json
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-7e8fd3caab9f> in <module>
# ----> 1 tea_name_json
#
# NameError: name 'tea_name_json' is not defined

# %%
tea_name_json = json.loads(tea_name_json)
tea_name_json
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-e2b863c0ce88> in <module>
# ----> 1 tea_name_json = json.loads(tea_name_json)
#       2 tea_name_json
#
# NameError: name 'json' is not defined

# %%
for key in tea_name_json.keys():
        print(tea_name_json['{}'.format(key)]['{}'.format(i)])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-0125cf333630> in <module>
# ----> 1 for key in tea_name_json.keys():
#       2         print(tea_name_json['{}'.format(key)]['{}'.format(i)])
#
# NameError: name 'tea_name_json' is not defined

# %% [markdown]
# ## 教师用户ID查询

# %%
tea_name_sql = ('''
    SELECT s.name,s.school_id ,u.ETT_USER_ID,oc.user_name , oc.password,t.TEACHER_NAME ,u.state_id, c.CLASS_ID,c.CLASS_GRADE,c.CLASS_NAME,c.PATTERN,sb.SUBJECT_NAME,jc.C_TIME
    from  oracle2utf.coschuser_info oc,user_info u,school_info s,teacher_info t ,j_class_user jc ,class_info c,subject_info sb
    where  oc.jid = u.ETT_USER_ID and u.DC_SCHOOL_ID = s.school_id and u.ref = t.user_id  and u.ref = jc.user_id  and jc.CLASS_ID = c.CLASS_ID and c.`YEAR` = '2020~2021' and jc.SUBJECT_ID = sb.SUBJECT_ID
    and oc.jid =  1007798979
    GROUP BY s.school_id ,u.ETT_USER_ID,c.CLASS_GRADE,c.CLASS_NAME,sb.SUBJECT_NAME
         ''')
tea_name = mysqlDB(tea_name_sql)
tea_name
# Out:
#             name  school_id  ETT_USER_ID user_name password TEACHER_NAME  \
# 0  兴义市民族师范学院附属中学  100002106   1007798979    魏敏xyfz  Aa12345           魏敏
#
#    state_id   CLASS_ID CLASS_GRADE CLASS_NAME PATTERN SUBJECT_NAME  \
# 0         0  100190530          初一      2006班     行政班           语文
#
#                C_TIME
# 0 2020-08-20 17:16:01

# %% [markdown]
# ## 学生用户名查询

# %%
stu_name_sql = ('''
    SELECT s.name,s.school_id ,u.ETT_USER_ID,oc.user_name , oc.password,t.STU_NAME ,u.state_id, c.CLASS_ID,c.CLASS_GRADE,c.CLASS_NAME,jc.C_TIME
    from  oracle2utf.user_info oc,user_info u,school_info s,student_info t ,j_class_user jc ,class_info c
    where  oc.user_id = u.ETT_USER_ID and u.DC_SCHOOL_ID = s.school_id and u.ref = t.user_id  and u.ref = jc.user_id  and jc.CLASS_ID = c.CLASS_ID and c.`YEAR` = '2020~2021'
    and oc.user_name ='大连测试002'
         ''')
stu_name = mysqlDB(stu_name_sql)
stu_name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-030b6c5ba471> in <module>
#       5     and oc.user_name ='大连测试002'
#       6          ''')
# ----> 7 stu_name = mysqlDB(stu_name_sql)
#       8 stu_name
#
# NameError: name 'mysqlDB' is not defined

# %%
stu1 =stu_name.to_json(orient = 'index', force_ascii = False)
import json
stu1 = json.loads(stu1)
type(stu1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-41ba98e190e4> in <module>
# ----> 1 stu1 =stu_name.to_json(orient = 'index', force_ascii = False)
#       2 import json
#       3 stu1 = json.loads(stu1)
#       4 type(stu1)
#
# NameError: name 'stu_name' is not defined

# %% [markdown]
# ## 学生用户ID查询

# %%
stu_name_sql = ('''
    SELECT s.name,s.school_id ,u.ETT_USER_ID,oc.user_name , oc.password,t.STU_NAME ,u.state_id, c.CLASS_ID,c.CLASS_GRADE,c.CLASS_NAME,jc.C_TIME
    from  oracle2utf.user_info oc,user_info u,school_info s,student_info t ,j_class_user jc ,class_info c
    where  oc.user_id = u.ETT_USER_ID and u.DC_SCHOOL_ID = s.school_id and u.ref = t.user_id  and u.ref = jc.user_id  and jc.CLASS_ID = c.CLASS_ID and c.`YEAR` = '2020~2021'
    and oc.user_id = 1007686434
         ''')
stu_name = mysqlDB(stu_name_sql)
stu_name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-e876f9b819e5> in <module>
#       5     and oc.user_id = 1007686434
#       6          ''')
# ----> 7 stu_name = mysqlDB(stu_name_sql)
#       8 stu_name
#
# NameError: name 'mysqlDB' is not defined

# %% [markdown]
# # 用户行为数据

# %%
body = '''{
  "query": {
    "bool": {
      "must": [
        {
          "term": {
            "jid": {
              "value": "1005223605"
            }
          }
        }
      ]
    }
  },"sort": [
    {
      "c_time": {
        "order": "asc"
      }
    }
  ],"size":10
  
}'''
res = es.search(index="two_month_action_logs", body=body)
res 
res = json.dumps(res)
# res = str(res)

with open('C:/Users/caozhiqiang/Desktop/行为数据.txt','a') as file:
    file.write(res)
    file.write('\n')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-4a663eac5f04> in <module>
#      21
#      22 }'''
# ---> 23 res = es.search(index="two_month_action_logs", body=body)
#      24 res
#      25 res = json.dumps(res)
#
# NameError: name 'es' is not defined

# %% [markdown]
# # excel转csv

# %%
el = pd.ExcelFile('F:/2、项目版本迭代/1、教学平台/102、考试分析/测试数据/学生每题作答 - 数据.xlsx')
sheet_names = el.sheet_names

for sheet_name in sheet_names:
    excel_file = pd.read_excel('F:/2、项目版本迭代/1、教学平台/102、考试分析/测试数据/学生每题作答 - 数据.xlsx',sheet_name='{}'.format(sheet_name))
    excel_file.to_csv('F:/2、项目版本迭代/1、教学平台/102、考试分析/测试数据/csv/{}.csv'.format(sheet_name))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-b44a26451198> in <module>
# ----> 1 el = pd.ExcelFile('F:/2、项目版本迭代/1、教学平台/102、考试分析/测试数据/学生每题作答 - 数据.xlsx')
#       2 sheet_names = el.sheet_names
#       3
#       4 for sheet_name in sheet_names:
#       5     excel_file = pd.read_excel('F:/2、项目版本迭代/1、教学平台/102、考试分析/测试数据/学生每题作答 - 数据.xlsx',sheet_name='{}'.format(sheet_name))
#
# NameError: name 'pd' is not defined
