# %%
def diamond(n):
    for i in range(n):
        if i <= n/2:
            print(' '*(n//2-i) + '#'*(2*i+1))
        else:
            print(' '*(i-n//2) + '#'*((n-i)*2-1))

diamond(11)
# Out:
#      #
#     ###
#    #####
#   #######
#  #########
# ###########
#  #########
#   #######
#    #####
#     ###
#      #

# %%
import os 
import pandas as pd

# %%
path = r'F:\9、测试\替换\音频'
files_name = os.listdir(path)
files_name_list = []
for i in files_name:
    files_name_list.append(i)
print(files_name_list)
# Out:
# ['22021.mp3', '22022.mp3', '22023.mp3', '22024.mp3', '22025.mp3', '22027.mp3', '22028.mp3', '22031.mp3', '22032.mp3', '22033.mp3', '22034.mp3', '22035.mp3', '22036.mp3', '22037.mp3', '22038.mp3', '22039.mp3', '22040.mp3', '22041.mp3', '22042.mp3', '22043.mp3', '22044.mp3', '22045.mp3', '22046.mp3', '22047.mp3', '22048.mp3', '22049.mp3', '22050.mp3', '22051.mp3', '22052.mp3', '22053.mp3', '22054.mp3', '22055.mp3', '22056.mp3', '22057.mp3', '22058.mp3', '22059.mp3', '22060.mp3', '22061.mp3', '22062.mp3', '22063.mp3', '22064.mp3', '22065.mp3', '22066.mp3', '22067.mp3', '22068.mp3', '22069.mp3', '22070.mp3', '22071.mp3', '22074.mp3', '22075.mp3', '22076.mp3', '22077.mp3', '22078.mp3', '22079.mp3', '22080.mp3', '22081.mp3', '22082.mp3', '22083.mp3', '22084.mp3', '22085.mp3', '22086.mp3', '22087.mp3', '22088.mp3', '22089.mp3', '22090.mp3', '22091.mp3', '22092.mp3', '22093.mp3', '22094.mp3', '22095.mp3', '22096.mp3', '22097.mp3', '22098.mp3', '22099.mp3', '22100.mp3', '22101.mp3', '22102.mp
# ...

# %%
excel = pd.read_excel("C:\\Users\\caozhiqiang\\Desktop\\单词.xlsx")
file_id_list = excel['ID'].to_list()
file_id_list
# Out:
# [22021,
#  22022,
#  22023,
#  22024,
#  22025,
#  22027,
#  22028,
#  22031,
#  22032,
#  22033,
#  22034,
#  22035,
#  22036,
#  22037,
#  22038,
#  22039,
#  22040,
#  22041,
#  22042,
#  22043,
#  22044,
#  22045,
#  22046,
#  22047,
#  22048,
#  22049,
#  22050,
#  22051,
#  22052,
#  22053,
#  22054,
#  22055,
#  22056,
#  22057,
#  22058,
#  22059,
#  22060,
#  22061,
#  22062,
#  22063,
#  22064,
#  22065,
#  22066,
#  22067,
#  22068,
#  22069,
#  22070,
#  22071,
#  22074,
#  22075,
#  22076,
#  22077,
#  22078,
#  22079,
#  22080,
#  22081,
#  22082,
#  22083,
#  22084,
#  22085,
#  22086,
#  22087,
#  22088,
#  22089,
#  22090,
#  22091,
#  22092,
#  22093,
#  22094,
#  22095,
#  22096,
#  22097,
#  22098,
#  22099,
#  22100,
#  22101,
#  22102,
#  22103,
#  22104,
#  22105,
#  22106,
#  22107,
#  22108,
#  22109,
#  22110,
#  22111,
#  22112,
#  22117,
#  22118,
#  22119,
#  22120,
#  22121,
#  22122,
#  22123,
#  22124,
#  22125,
#  22126,
#  22127,
#  22128,
#  22129,
# ...

# %%
for i in range(len(file_id_list)-1):
    old_name = str(path + os.sep + files_name_list[i])
    new_name = str(path + os.sep + str(file_id_list[i]) + '.mp3')
    os.rename(old_name,new_name)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-61-ff0bf684db73> in <module>
#       1 for i in range(len(file_id_list)-1):
# ----> 2     old_name = str(path + os.sep + files_name_list[i])
#       3     new_name = str(path + os.sep + str(file_id_list[i])+'.mp3')
#       4     os.rename(old_name,new_name)
#
# IndexError: list index out of range
