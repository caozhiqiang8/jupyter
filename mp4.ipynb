# %%
from sqlalchemy import create_engine
import pandas as pd

# %%
def mysql_connect(sql):
    engine = create_engine(
        'mysql+pymysql://schu:slavep@123.103.75.152:3306/school')
    result = pd.read_sql_query(sql=sql, con=engine)
    return result

# %%
sql = '''
SELECT res_id ,res_name,ROUND(rs.file_size/1024/1024/1024,2) "文件大小(G)" ,rs.DC_SCHOOL_ID,fr.name,oc.user_name ,oc.password,rs.c_time  ,CONCAT("https://cdn1-school.ai-classes.com/fpupload/",file_path,"001.mp4") "文件地址"
from rs_resource_info rs , user_info  u  ,oracle2utf.coschuser_info oc ,  franchised_school_info fr  
where rs.FILE_SUFFIXNAME = '.mp4'  and rs.user_id = u.user_id and oc.jid = u.ett_user_id and fr.school_id = u.dc_school_id   
and rs.file_size/1024/1024 >  100  
ORDER BY rs.user_name desc ,rs.c_time desc 
'''
res = mysql_connect(sql)
res
# Out:
#               res_id            res_name  文件大小(G)  DC_SCHOOL_ID  \
# 0     -5153629169415                1441     0.13       53206.0
# 1     -4536981484561         《两弹元勋——邓稼先》     0.27       53206.0
# 2     -3129370462395             句子衔接与排序     0.17       53206.0
# 3     -2982853607622          句子衔接与排序（二）     0.19       53206.0
# 4     -3903177328749         《巨人的花园》第二课时     0.17   100000421.0
# ...              ...                 ...      ...           ...
# 97722 -5049957143263               第二十五题     0.22       53557.0
# 97723 -4942115626024               第二十四题     0.23       53557.0
# 97724 -4824448490959               第二十二题     0.23       53557.0
# 97725  -979927557253        逮虾户- DEJA VU     0.11       53795.0
# 97726  -763829741650  西班牙的浪漫 - Despacito     0.10       53795.0
#
#                 name user_name          password              c_time  \
# 0         湖北省恩施市英才学校   龚雅雯esyc       gyw05200020 2022-05-07 08:59:13
# ...
